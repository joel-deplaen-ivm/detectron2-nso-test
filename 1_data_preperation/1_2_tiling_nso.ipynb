# %%
import pandas as pd
import json
import os
os.environ['USE_PYGEOS'] = '0'
import geopandas as gpd
import shapely
import rasterio
import json
import pyproj
import numpy as np
from pathlib import Path
import multiprocessing

root = "/scistor/ivm/project/NSO/timeseries_50_baseline"
big_tiles_folder = root + "/big_tiles"
small_tiles_folder = root + "/small_tiles"
annotation_path = root + "/annotations_shp/fixed_substations_NL_annotations.shp"
json_folder = root + "/geojsons"

# %%
def split_geotiff(rasters_path, output_dir, width, height, pixel_size):
    """
    This function splits a given geotiff raster image into multiple tiles with a specified width and height.

    Parameters:
    rasters_path (str): File path to the input folder with the rasters.
    output_dir (str): File path to the output folder where the created tiles will be saved.
    width (int): Width of the tiles in pixels.
    height (int): Height of the tiles in pixels.
    pixel_size (float): Pixel size of the raster.

    Returns:
    None
    """
    # Get a list of all files in the directory and then get a list of all .tifs
    files = os.listdir(rasters_path)
    tif_files = [file for file in files if file.endswith(".tif")]
    
    i = 0
    # Iterate through all the raster files in the input directory if ends with "tif"
    for tif_file in tif_files:
        i+=1
        print('splitting tile', i)
        img_id = tif_file.split(".tif")[0]
        raster = os.path.join(rasters_path, tif_file)
        # Open the input raster file using rasterio.open() and read the raster image and metadata information
        with rasterio.open(raster) as src:
            out_image = src.read()
            out_meta = src.meta
            out_transform = src.transform
            
            # Calculate the heights and widths of the tiles based on the specified width and height parameters
            heights = np.arange(0, out_image.shape[1], height)
            widths = np.arange(0, out_image.shape[2], width)
            
            # Extract the origin x (min) and y(max) of the raster image
            min_x = out_transform[2]
            max_y = out_transform[5]

            # Iterate through all the tiles and create a new tile image
            for x in range(len(heights)):
                for y in range(len(widths)):
                    # Skip the last tile if it is smaller than the specified height or width
                    if (x + 1 == len(heights)) or (y + 1 == len(widths)):
                        continue
                    else:
                        # Extract the new tile from the input raster using slice operation
                        new_tile = out_image[:, heights[x]:heights[x+1], widths[y]:widths[y+1]]
                        
                        # skip tiles if percentage black pixels is higher than 10%
                        if np.count_nonzero((new_tile[0] == 0) & (new_tile[1] == 0) & (new_tile[2] == 0)) > 0.1*new_tile[0].size:
                            continue
                        else:
                            # Calculate the transform for the new tile using rasterio.transform.from_origin() function
                            transform_new = rasterio.transform.from_origin(min_x + widths[y]/2, max_y - heights[x]/2, pixel_size, pixel_size)
                            
                            # Update the metadata information for the new tile
                            out_meta.update({"driver": "GTiff",
                                            "height": new_tile.shape[1],
                                            "width": new_tile.shape[2],
                                            "transform": transform_new})
                            
                            # Save the new tile to the output directory using rasterio.open() and dest.write() functions
                            with rasterio.open(os.path.join(output_dir, "{}_{}_{}_{}.tif".format(i, img_id, heights[x], widths[y])),
                                            "w", compress='lzw', **out_meta) as dest:
                                dest.write(new_tile)
        print('done splitting tile', i)

# %%
def split_single_geotiff(tif_file, rasters_path, output_dir, width, height, pixel_size):
    print('starting')
    img_id = tif_file.split(".tif")[0]
    raster = os.path.join(rasters_path, tif_file)
    # Open the input raster file using rasterio.open() and read the raster image and metadata information
    with rasterio.open(raster) as src:
        out_image = src.read()
        out_meta = src.meta
        out_transform = src.transform
        
        # Calculate the heights and widths of the tiles based on the specified width and height parameters
        heights = np.arange(0, out_image.shape[1], height)
        widths = np.arange(0, out_image.shape[2], width)
        
        # Extract the origin x (min) and y(max) of the raster image
        min_x = out_transform[2]
        max_y = out_transform[5]

        # Iterate through all the tiles and create a new tile image
        for x in range(len(heights)):
            for y in range(len(widths)):
                # Skip the last tile if it is smaller than the specified height or width
                if (x + 1 == len(heights)) or (y + 1 == len(widths)):
                    continue
                else:
                    new_tile = out_image[:, heights[x]:heights[x+1], widths[y]:widths[y+1]]
                    # skip tiles if percentage black pixels is higher than 10%
                    if np.count_nonzero((new_tile[0] == 0) & (new_tile[1] == 0) & (new_tile[2] == 0)) > 0.1*new_tile[0].size:
                        continue
                    else:
                        # Extract the new tile from the input raster using slice operation
                        
                        # Calculate the transform for the new tile using rasterio.transform.from_origin() function
                        transform_new = rasterio.transform.from_origin(min_x + widths[y]/2, max_y - heights[x]/2, pixel_size, pixel_size)
                        
                        # Update the metadata information for the new tile
                        out_meta.update({"driver": "GTiff",
                                        "height": new_tile.shape[1],
                                        "width": new_tile.shape[2],
                                        "transform": transform_new})
                        
                        # Save the new tile to the output directory using rasterio.open() and dest.write() functions
                        with rasterio.open(os.path.join(output_dir, "{}_{}_{}.tif".format(img_id, heights[x], widths[y])),
                                        "w", compress='lzw', **out_meta) as dest:
                            dest.write(new_tile)

    print('done splitting tile', img_id)

# %%
def reproject(df_ds, current_crs, approximate_crs):
    """Reproject a geodataframe of a shapefile from one CRS to another.

    Args:
        df_ds (DataFrame): A geodataframe of a shapefile layer.
        current_crs (str): The EPSG code of the current CRS of the shapefile.
        approximate_crs (str): The EPSG code of the target CRS.

    Returns:
        DataFrame: A geodataframe of a shapefile layer with the new coordinate reference system.
    """

    # Extract the geometries from the geodataframe
    geometries = df_ds['geometry']
    
    # Extract the coordinates of the geometries
    coords = shapely.get_coordinates(geometries)
    
    # Set up a coordinate transformer to transform from the current CRS to the target CRS
    transformer = pyproj.Transformer.from_crs(current_crs, approximate_crs, always_xy=True)
    
    # Transform the coordinates to the target CRS
    new_coords = transformer.transform(coords[:, 0], coords[:, 1])
    
    # Update the geometries in the original geodataframe with the transformed coordinates
    return shapely.set_coordinates(geometries.copy(), np.array(new_coords).T)

# %%
def split_annotations_to_geojson(df, small_tiles_folder, geojson_folder):
    """
    Split annotations data into the raster tiles and convert to the format of train-net.py: 
    Pygeos to GPD to geojson.

    Args:
    df (GeoDataFrame): Vector dataset containing features to split.
    tiles_path (str): Path to the directory where the raster tiles are stored
    geojson_folder (str): Path to the directory where the output geojson files will be saved
    
    Returns:
    None
    """
    # Create spatial index for faster query
    #spatial index are the bounding boxes of the asset geometries
    spatial_index = shapely.STRtree(df.geometry)
    id_obj = 0
    
    # Get a list of all files in the directory
    files = os.listdir(small_tiles_folder)

    # Filter for only the files that end with ".tif"
    tif_tiles = [file for file in files if file.endswith(".tif")]

    # Iterate through each raster tile
    for tile in tif_tiles:
        input_file = os.path.join(small_tiles_folder,tile)
        with rasterio.open(input_file) as src:
            out_image = src.read()
            out_meta = src.meta
        # geom is the bounding box of the raster tile
        geom = shapely.box(*src.bounds)
        
        # Query overlapping geometries from geom (tile) and the asset (from the spatial index)
        check_overlaps = spatial_index.query(geom, predicate='intersects')

        # Create new geojson file for each overlapping geometry
        if len(check_overlaps) > 0:   
            print('found overlaps')         
            get_matches = df.iloc[check_overlaps]
            get_exact_overlap = shapely.intersection(get_matches['geometry'].values, geom)
            df_objs = pd.DataFrame()
            for shapely_geom, included_r, area in zip(get_exact_overlap, get_matches['Included'], get_matches['area']): # adjusted so that other data is also passed
                id_obj += 1
                df_row = pd.DataFrame()
                included = 1 if included_r == 1.0 else 0
                df_row['properties'] = [{"id": id_obj,
                                         "included": included,
                                         "area": area,
                                         "building": "yes"}]
                #convert shapely geometry to geopandas geometry
                df_row['geometry'] = gpd.GeoSeries([shapely_geom])
                df_objs = pd.concat([df_objs, df_row], ignore_index=True) # maybe check for different method
            print(df_objs)
            gdf_obj = gpd.GeoDataFrame(df_objs, geometry='geometry', crs="epsg:28992")
            gdf_obj.set_geometry(col='geometry', inplace=True)
                
            img_id = tile.split(".tif")[0]
            gdf_obj.to_file(os.path.join(geojson_folder, "{}.geojson".format(img_id)), driver="GeoJSON")

# split_annotations_to_geojson(df, small_tiles_folder, json_folder)

# %%
### This script processes the tiles parallel

width = 1000 #width of the new tiles
height = 1000 #height of the new tiles
nso_pix = 0.5 #pixel size of the tiles

#make output directory if does not exist
if not os.path.exists(small_tiles_folder):
    os.makedirs(small_tiles_folder)

# Get a list of all files in the directory
files = os.listdir(big_tiles_folder)
tif_files = [file for file in files if file.endswith(".tif")]

num_processes = multiprocessing.cpu_count() // 10
print('using', num_processes, 'CPUs')
pool = multiprocessing.Pool(processes=num_processes)

# Map the cutting function to each .tif file using multiple processes
args=[(tif_file, big_tiles_folder, small_tiles_folder, width, height, nso_pix) for tif_file in tif_files]
pool.starmap(split_single_geotiff, args)

pool.close()
pool.join()
pool.terminate()

# %%
### This script tests if all tiles are properly processed

files = os.listdir(big_tiles_folder)
names = [file.strip(".tif") for file in files if file.endswith(".tif")]

small_tiles = os.listdir(small_tiles_folder)
for name in names:
    contains = [small for small in small_tiles if name in small]
    print(f'The tif file named {name} has {len(contains)} small_tiles')
# Out:
# The tif file named 20220316_110548_SV1-04_SV_RD_8bit_RGB_50cm_Hoogkarspel has 599 small_tiles
# The tif file named 20220724_110831_SV1-04_SV_RD_8bit_RGB_50cm_Oostvaardersplassen has 634 small_tiles
# The tif file named 20220303_101830_SV1-01_SV_RD_8bit_RGB_50cm_Geldrop has 656 small_tiles
# The tif file named 20221009_105653_SV1-04_SV_RD_8bit_RGB_50cm_Veldhoven has 631 small_tiles
# The tif file named 20220719_105318_SV1-04_SV_RD_8bit_RGB_50cm_Heel has 624 small_tiles
# The tif file named 20220813_105359_SV1-03_SV_RD_8bit_RGB_50cm_Hunsel has 627 small_tiles
# The tif file named 20220322_111229_SV1-04_SV_RD_8bit_RGB_50cm_CapelleAanDenIJssel has 631 small_tiles
# The tif file named 20221009_111423_SV1-03_SV_RD_8bit_RGB_50cm_Rhoon has 709 small_tiles
# The tif file named 20220424_105500_SV1-04_SV_RD_8bit_RGB_50cm_Hattem has 645 small_tiles
# The tif file named 20220424_105511_SV1-04_SV_RD_8bit_RGB_50cm_Beuningen has 642 small_tiles
# The tif file named 20220623_103209_SV1-01_SV_RD_8bit_RGB_50cm_Amsterdam has 661 small_tiles
# The tif file named 20230111_105152_SV1-04_SV_RD_8bit_RGB_50cm_Holwerd has 659 small_tiles
# The tif file named 20220813_105343_SV1-03_SV_RD_8bit_RGB_50cm_Zutphen has 626 small_tiles
# The tif file named 20220724_110844_SV1-04_SV_RD_8bit_RGB_50cm_Dongen has 633 small_tiles
# The tif file named 20220830_110402_SV1-03_SV_RD_8bit_RGB_50cm_Purmerend has 598 small_tiles
# The tif file named 20221009_105644_SV1-04_SV_RD_8bit_RGB_50cm_Rhenen has 618 small_tiles
# The tif file named 20221009_105642_SV1-04_SV_RD_8bit_RGB_50cm_Lunteren has 625 small_tiles
# The tif file named 20220711_103408_SV1-01_SV_RD_8bit_RGB_50cm_Middelburg has 657 small_tiles
# The tif file named 20220509_104756_SV1-03_SV_RD_8bit_RGB_50cm_Winterswijk has 700 small_tiles
# The tif file named 20210907_113722_SV1-02_SV_RD_8bit_RGB_50cm_Sneekermeer has 612 small_tiles
# The tif file named 20221119_104718_SV1-03_SV_RD_8bit_RGB_50cm_Kampen has 732 small_tiles
# The tif file named 20220424_105506_SV1-04_SV_RD_8bit_RGB_50cm_Veluwe has 642 small_tiles
# The tif file named 20221112_111204_SV1-03_SV_RD_8bit_RGB_50cm_Oosterhou has 704 small_tiles
# The tif file named 20220719_105317_SV1-04_SV_RD_8bit_RGB_50cm_Helden has 625 small_tiles
# The tif file named 20220509_113001_SV1-02_SV_RD_8bit_RGB_50cm_Emmeloord has 635 small_tiles
# The tif file named 20220623_103210_SV1-01_SV_RD_8bit_RGB_50cm_Schiphol has 661 small_tiles
# The tif file named 20221113_105519_SV1-03_SV_RD_8bit_RGB_50cm_Kerkrade has 599 small_tiles
# The tif file named 20220903_111726_SV1-04_SV_RD_8bit_RGB_50cm_HoekVanHolland has 720 small_tiles
# The tif file named 20220813_105352_SV1-03_SV_RD_8bit_RGB_50cm_Boxmeer has 628 small_tiles
# The tif file named 20220712_110839_SV1-04_SV_RD_8bit_RGB_50cm_Vosdonk has 605 small_tiles
# The tif file named 20220813_105403_SV1-03_SV_RD_8bit_RGB_50cm_Maasmechelen_BE has 636 small_tiles
# The tif file named 20221009_105647_SV1-04_SV_RD_8bit_RGB_50cm_Heesch has 619 small_tiles
# The tif file named 20220812_105120_SV1-04_SV_RD_8bit_RGB_50cm_Oldenzaal has 713 small_tiles
# The tif file named 20220303_101829_SV1-01_SV_RD_8bit_RGB_50cm_Helmond has 653 small_tiles
# The tif file named 20220906_104556_SV1-03_SV_RD_8bit_RGB_50cm_Venlo has 738 small_tiles
# The tif file named 20220302_112114_SV1-04_SV_RD_8bit_RGB_50cm_Zuidland has 791 small_tiles
# The tif file named 20220719_105243_SV1-04_SV_RD_8bit_RGB_50cm_Loppersum has 627 small_tiles

# %%
### Reproject annotation shapefile crs to the same crs as the raster tiles ###

annotations_crs = "epsg:4326"
raster_crs = "epsg:28992"
# read and reproject annotations
df = pd.DataFrame(gpd.read_file(annotation_path).copy())
df.geometry = reproject(df, annotations_crs, raster_crs)
print(len(df))
print(df.columns)
print('done')
# Out:
# 229
# Index(['annotator', 'origin', 'Included', 'area', 'geometry'], dtype='object')
# done

# %%
### Spliting annotations shapefile into the raster tiles & save it to geojson ###

# Make folder for geojsons
if not os.path.exists(json_folder):
    os.makedirs(json_folder)

# Split annotations data into the new raster tiles of width X and height Y
split_annotations_to_geojson(df, small_tiles_folder, json_folder)
print('done')
# Out:
# found overlaps
#                                           properties
# 0  {'id': 1, 'included': 0, 'area': 2084, 'buildi...  \
#
#                                             geometry
# 0  POLYGON ((248494.325 607802.755, 248498.883 60...
# found overlaps
#                                           properties
# 0  {'id': 2, 'included': 0, 'area': 11619, 'build...  \
#
#                                             geometry
# 0  MULTIPOLYGON (((164932.410 384147.749, 164929....
# found overlaps
#                                           properties
# 0  {'id': 3, 'included': 0, 'area': 2235, 'buildi...  \
#
#                                             geometry
# 0  MULTIPOLYGON (((76888.446 433996.689, 76891.49...
# found overlaps
#                                           properties
# 0  {'id': 4, 'included': 0, 'area': 5973, 'buildi...  \
#
#                                             geometry
# 0  POLYGON ((182020.681 425892.307, 182020.118 42...
# found overlaps
#                                           properties
# 0  {'id': 5, 'included': 0, 'area': 11619, 'build...  \
# 1  {'id': 6, 'included': 1, 'area': 31924, 'build...
#
#                                             geometry
# 0  MULTIPOLYGON (((164951.182 384047.654, 164969....
# 1  POLYGON ((165041.285 384121.798, 164983.494 38...
# found overlaps
#                                           properties
# 0  {'id': 7, 'included': 0, 'area': 34668, 'build...  \
#
#                                             geometry
# 0  POLYGON ((174026.000 437775.728, 174026.000 43...
# found overlaps
#                                           properties
# 0  {'id': 8, 'included': 0, 'area': 1425, 'buildi...  \
#
#                                             geometry
# 0  MULTIPOLYGON (((195955.532 354869.912, 195956....
# found overlaps
#                                           properties
# 0  {'id': 9, 'included': 0, 'area': 24558, 'build...  \
#
#                                             geometry
# 0  POLYGON ((191418.949 405838.646, 191444.584 40...
# found overlaps
#                                           properties
# 0  {'id': 10, 'included': 1, 'area': 6994, 'build...  \
#
#                                             geometry
# 0  POLYGON ((174466.465 385649.162, 174465.931 38...
# found overlaps
#                                           properties
# 0  {'id': 11, 'included': 0, 'area': 9446, 'build...  \
#
#                                             geometry
# 0  POLYGON ((183526.174 334773.118, 183519.971 33...
# found overlaps
#                                           properties
# 0  {'id': 12, 'included': 1, 'area': 5849, 'build...  \
#
#                                             geometry
# 0  POLYGON ((194784.568 468252.978, 194784.712 46...
# found overlaps
#                                           properties
# 0  {'id': 13, 'included': 1, 'area': 18166, 'buil...  \
# 1  {'id': 14, 'included': 1, 'area': 42317, 'buil...
#
#                                             geometry
# 0  POLYGON ((102828.733 436198.494, 102824.185 43...
# 1  MULTIPOLYGON (((102781.282 436531.205, 102793....
# found overlaps
#                                           properties
# 0  {'id': 15, 'included': 0, 'area': 34668, 'buil...  \
#
#                                             geometry
# 0  POLYGON ((174020.263 437567.922, 174026.000 43...
# found overlaps
#                                           properties
# 0  {'id': 16, 'included': 0, 'area': 4288, 'build...  \
#
#                                             geometry
# 0  POLYGON ((204709.514 381688.073, 204701.342 38...
# found overlaps
#                                           properties
# 0  {'id': 17, 'included': 0, 'area': 2261, 'build...  \
#
#                                             geometry
# 0  POLYGON ((252836.348 604642.424, 252839.683 60...
# found overlaps
#                                           properties
# 0  {'id': 18, 'included': 0, 'area': 5973, 'build...  \
#
#                                             geometry
# 0  MULTIPOLYGON (((182066.380 425823.819, 182068....
# found overlaps
#                                           properties
# 0  {'id': 19, 'included': 0, 'area': 6210, 'build...  \
#
#                                             geometry
# 0  POLYGON ((160472.497 380030.437, 160493.278 38...
# found overlaps
#                                           properties
# 0  {'id': 20, 'included': 0, 'area': 4121, 'build...  \
#
#                                             geometry
# 0  POLYGON ((123104.000 406569.386, 123104.000 40...
# found overlaps
#                                           properties
# 0  {'id': 21, 'included': 1, 'area': 3394, 'build...  \
#
#                                             geometry
# 0  POLYGON ((34242.843 390235.698, 34266.035 3902...
# found overlaps
#                                           properties
# 0  {'id': 22, 'included': 1, 'area': 2538, 'build...  \
#
#                                             geometry
# 0  POLYGON ((188466.769 508196.245, 188471.625 50...
# found overlaps
#                                           properties
# 0  {'id': 23, 'included': 0, 'area': 4121, 'build...  \
#
#                                             geometry
# 0  MULTIPOLYGON (((123106.575 406567.017, 123096....
# found overlaps
#                                           properties
# 0  {'id': 24, 'included': 1, 'area': 2146, 'build...  \
#
#                                             geometry
# 0  POLYGON ((195063.682 411781.348, 195074.618 41...
# found overlaps
#                                           properties
# 0  {'id': 25, 'included': 1, 'area': 2677, 'build...  \
#
#                                             geometry
# 0  POLYGON ((66028.154 441915.548, 66017.581 4418...
# found overlaps
#                                           properties
# 0  {'id': 26, 'included': 1, 'area': 12879, 'buil...  \
#
#                                             geometry
# 0  MULTIPOLYGON (((118284.877 490728.676, 118279....
# found overlaps
#                                           properties
# 0  {'id': 27, 'included': 0, 'area': 1274, 'build...  \
#
#                                             geometry
# 0  POLYGON ((193840.936 509485.227, 193847.644 50...
# found overlaps
#                                           properties
# 0  {'id': 28, 'included': 1, 'area': 2775, 'build...  \
#
#                                             geometry
# 0  POLYGON ((200956.925 504092.772, 200976.230 50...
# found overlaps
#                                           properties
# 0  {'id': 29, 'included': 0, 'area': 3173, 'build...  \
#
#                                             geometry
# 0  POLYGON ((204881.196 501775.411, 204888.679 50...
# found overlaps
#                                           properties
# 0  {'id': 30, 'included': 1, 'area': 8362, 'build...  \
#
#                                             geometry
# 0  POLYGON ((174006.326 451912.258, 174008.517 45...
# found overlaps
#                                           properties
# 0  {'id': 31, 'included': 1, 'area': 4694, 'build...  \
#
#                                             geometry
# 0  MULTIPOLYGON (((112508.582 402383.267, 112514....
# found overlaps
#                                           properties
# 0  {'id': 32, 'included': 1, 'area': 2243, 'build...  \
#
#                                             geometry
# 0  POLYGON ((168160.299 446466.770, 168152.249 44...
# found overlaps
#                                           properties
# 0  {'id': 33, 'included': 0, 'area': 1071, 'build...  \
# 1  {'id': 34, 'included': 1, 'area': 8362, 'build...
#
#                                             geometry
# 0  POLYGON ((174094.313 451770.457, 174095.191 45...
# 1  MULTIPOLYGON (((174078.188 451844.347, 174077....
# found overlaps
#                                           properties
# 0  {'id': 35, 'included': 0, 'area': 12807, 'buil...  \
#
#                                             geometry
# 0  POLYGON ((120205.113 493669.500, 120261.856 49...
# found overlaps
#                                           properties
# 0  {'id': 36, 'included': 1, 'area': 65165, 'buil...  \
#
#                                             geometry
# 0  POLYGON ((191949.953 351066.598, 191956.000 35...
# found overlaps
#                                           properties
# 0  {'id': 37, 'included': 0, 'area': 3173, 'build...  \
#
#                                             geometry
# 0  MULTIPOLYGON (((204892.246 501760.000, 204901....
# found overlaps
#                                           properties
# 0  {'id': 38, 'included': 0, 'area': 37807, 'buil...  \
#
#                                             geometry
# 0  POLYGON ((116633.475 412610.452, 116596.000 41...
# found overlaps
#                                           properties
# 0  {'id': 39, 'included': 1, 'area': 42317, 'buil...  \
#
#                                             geometry
# 0  POLYGON ((102823.564 436574.586, 102821.916 43...
# found overlaps
#                                           properties
# 0  {'id': 40, 'included': 1, 'area': 6126, 'build...  \
#
#                                             geometry
# 0  POLYGON ((100942.964 398516.279, 100946.898 39...
# found overlaps
#                                           properties
# 0  {'id': 41, 'included': 0, 'area': 12807, 'buil...  \
#
#                                             geometry
# 0  POLYGON ((120218.353 493673.834, 120257.046 49...
# found overlaps
#                                           properties
# 0  {'id': 42, 'included': 1, 'area': 5221, 'build...  \
#
#                                             geometry
# 0  POLYGON ((129920.953 401245.037, 129927.104 40...
# found overlaps
#                                           properties
# 0  {'id': 43, 'included': 1, 'area': 4812, 'build...  \
#
#                                             geometry
# 0  POLYGON ((245328.789 443709.152, 245323.662 44...
# found overlaps
#                                           properties
# 0  {'id': 44, 'included': 1, 'area': 9829, 'build...  \
#
#                                             geometry
# 0  POLYGON ((186001.552 429993.844, 185985.000 42...
# found overlaps
#                                           properties
# 0  {'id': 45, 'included': 1, 'area': 21152, 'buil...  \
#
#                                             geometry
# 0  POLYGON ((88707.993 433418.002, 88707.982 4334...
# found overlaps
#                                           properties
# 0  {'id': 46, 'included': 1, 'area': 4812, 'build...  \
#
#                                             geometry
# 0  POLYGON ((245304.896 443748.658, 245302.514 44...
# found overlaps
#                                           properties
# 0  {'id': 47, 'included': 1, 'area': 24460, 'buil...  \
#
#                                             geometry
# 0  POLYGON ((253083.157 606420.946, 253065.736 60...
# found overlaps
#                                           properties
# 0  {'id': 48, 'included': 1, 'area': 22028, 'buil...  \
#
#                                             geometry
# 0  MULTIPOLYGON (((192456.289 351025.180, 192456....
# found overlaps
#                                           properties
# 0  {'id': 49, 'included': 1, 'area': 12879, 'buil...  \
#
#                                             geometry
# 0  POLYGON ((118355.904 490662.491, 118359.783 49...
# found overlaps
#                                           properties
# 0  {'id': 50, 'included': 1, 'area': 15270, 'buil...  \
#
#                                             geometry
# 0  POLYGON ((195632.404 359607.600, 195638.768 35...
# found overlaps
#                                           properties
# 0  {'id': 51, 'included': 1, 'area': 6628, 'build...  \
#
#                                             geometry
# 0  POLYGON ((196570.274 368801.858, 196553.100 36...
# found overlaps
#                                           properties
# 0  {'id': 52, 'included': 0, 'area': 900, 'buildi...  \
#
#                                             geometry
# 0  POLYGON ((173098.389 441317.957, 173099.022 44...
# found overlaps
#                                           properties
# 0  {'id': 53, 'included': 1, 'area': 2933, 'build...  \
#
#                                             geometry
# 0  POLYGON ((194582.253 593649.204, 194586.603 59...
# found overlaps
#                                           properties
# 0  {'id': 54, 'included': 1, 'area': 15985, 'buil...  \
#
#                                             geometry
# 0  MULTIPOLYGON (((174526.275 437904.411, 174526....
# found overlaps
#                                           properties
# 0  {'id': 55, 'included': 1, 'area': 5869, 'build...  \
#
#                                             geometry
# 0  POLYGON ((146719.189 485899.925, 146715.058 48...
# found overlaps
#                                           properties
# 0  {'id': 56, 'included': 0, 'area': 6210, 'build...  \
#
#                                             geometry
# 0  MULTIPOLYGON (((160472.235 380087.629, 160472....
# found overlaps
#                                           properties
# 0  {'id': 57, 'included': 0, 'area': 244, 'buildi...  \
#
#                                             geometry
# 0  POLYGON ((113687.035 474307.350, 113692.756 47...
# found overlaps
#                                           properties
# 0  {'id': 58, 'included': 1, 'area': 24460, 'buil...  \
#
#                                             geometry
# 0  POLYGON ((253159.982 606562.798, 253149.612 60...
# found overlaps
#                                           properties
# 0  {'id': 59, 'included': 0, 'area': 4753, 'build...  \
#
#                                             geometry
# 0  POLYGON ((202155.965 496471.189, 202141.384 49...
# found overlaps
#                                           properties
# 0  {'id': 60, 'included': 1, 'area': 42317, 'buil...  \
#
#                                             geometry
# 0  MULTIPOLYGON (((102935.796 436602.950, 102930....
# found overlaps
#                                           properties
# 0  {'id': 61, 'included': 1, 'area': 2958, 'build...  \
#
#                                             geometry
# 0  POLYGON ((174690.834 391370.643, 174672.412 39...
# found overlaps
#                                           properties
# 0  {'id': 62, 'included': 0, 'area': 4288, 'build...  \
#
#                                             geometry
# 0  POLYGON ((204774.996 381750.320, 204781.186 38...
# found overlaps
#                                           properties
# 0  {'id': 63, 'included': 1, 'area': 2435, 'build...  \
#
#                                             geometry
# 0  POLYGON ((184856.855 360878.185, 184862.439 36...
# found overlaps
#                                           properties
# 0  {'id': 64, 'included': 1, 'area': 8434, 'build...  \
#
#                                             geometry
# 0  POLYGON ((136682.959 523302.386, 136664.064 52...
# found overlaps
#                                           properties
# 0  {'id': 65, 'included': 1, 'area': 5953, 'build...  \
#
#                                             geometry
# 0  POLYGON ((159046.354 385904.412, 159037.092 38...
# found overlaps
#                                           properties
# 0  {'id': 66, 'included': 0, 'area': 1079, 'build...  \
#
#                                             geometry
# 0  POLYGON ((253523.321 605834.724, 253516.376 60...
# found overlaps
#                                           properties
# 0  {'id': 67, 'included': 1, 'area': 9829, 'build...  \
#
#                                             geometry
# 0  POLYGON ((185867.270 430094.115, 185857.217 43...
# found overlaps
#                                           properties
# 0  {'id': 68, 'included': 0, 'area': 4329, 'build...  \
#
#                                             geometry
# 0  POLYGON ((74871.952 443871.498, 74878.270 4438...
# found overlaps
#                                           properties
# 0  {'id': 69, 'included': 0, 'area': 23301, 'buil...  \
#
#                                             geometry
# 0  POLYGON ((117295.213 411948.019, 117295.977 41...
# found overlaps
#                                           properties
# 0  {'id': 70, 'included': 0, 'area': 37807, 'buil...  \
#
#                                             geometry
# 0  MULTIPOLYGON (((116596.000 412594.750, 116596....
# found overlaps
#                                           properties
# 0  {'id': 71, 'included': 1, 'area': 8768, 'build...  \
# 1  {'id': 72, 'included': 1, 'area': 3530, 'build...
#
#                                             geometry
# 0  POLYGON ((122343.763 502397.663, 122334.679 50...
# 1  POLYGON ((122376.844 502461.520, 122393.907 50...
# found overlaps
#                                           properties
# 0  {'id': 73, 'included': 1, 'area': 3096, 'build...  \
#
#                                             geometry
# 0  POLYGON ((178839.233 568557.317, 178928.742 56...
# found overlaps
#                                           properties
# 0  {'id': 74, 'included': 1, 'area': 15270, 'buil...  \
#
#                                             geometry
# 0  MULTIPOLYGON (((195665.759 359687.357, 195656....
# found overlaps
#                                           properties
# 0  {'id': 75, 'included': 1, 'area': 22028, 'buil...  \
# 1  {'id': 76, 'included': 1, 'area': 65165, 'buil...
#
#                                             geometry
# 0  MULTIPOLYGON (((192372.265 350968.903, 192392....
# 1  POLYGON ((192163.732 351042.571, 192153.808 35...
# found overlaps
#                                           properties
# 0  {'id': 77, 'included': 1, 'area': 21152, 'buil...  \
#
#                                             geometry
# 0  POLYGON ((88518.000 433489.436, 88518.000 4334...
# found overlaps
#                                           properties
# 0  {'id': 78, 'included': 1, 'area': 8609, 'build...  \
#
#                                             geometry
# 0  POLYGON ((77665.621 428505.253, 77660.504 4284...
# found overlaps
#                                           properties
# 0  {'id': 79, 'included': 1, 'area': 2377, 'build...  \
#
#                                             geometry
# 0  POLYGON ((117752.076 479884.896, 117755.281 47...
# found overlaps
#                                           properties
# 0  {'id': 80, 'included': 1, 'area': 65165, 'buil...  \
#
#                                             geometry
# 0  POLYGON ((192055.519 351175.355, 192115.990 35...
# found overlaps
#                                           properties
# 0  {'id': 81, 'included': 1, 'area': 42317, 'buil...  \
#
#                                             geometry
# 0  MULTIPOLYGON (((102982.159 436529.111, 102992....
# found overlaps
#                                           properties
# 0  {'id': 82, 'included': 1, 'area': 5849, 'build...  \
#
#                                             geometry
# 0  POLYGON ((194758.153 468273.220, 194756.898 46...
# found overlaps
#                                           properties
# 0  {'id': 83, 'included': 0, 'area': 34668, 'buil...  \
#
#                                             geometry
# 0  MULTIPOLYGON (((174115.555 437564.810, 174109....
# found overlaps
#                                           properties
# 0  {'id': 84, 'included': 1, 'area': 2933, 'build...  \
#
#                                             geometry
# 0  POLYGON ((194555.256 593622.649, 194574.000 59...
# found overlaps
#                                           properties
# 0  {'id': 85, 'included': 1, 'area': 2538, 'build...  \
#
#                                             geometry
# 0  POLYGON ((188409.063 508135.162, 188404.316 50...
# found overlaps
#                                           properties
# 0  {'id': 86, 'included': 0, 'area': 34668, 'buil...  \
# 1  {'id': 87, 'included': 1, 'area': 15985, 'buil...
#
#                                             geometry
# 0  POLYGON ((174066.432 437765.662, 174062.580 43...
# 1  MULTIPOLYGON (((174471.128 437873.899, 174483....
# found overlaps
#                                           properties
# 0  {'id': 88, 'included': 1, 'area': 6994, 'build...  \
#
#                                             geometry
# 0  POLYGON ((174427.527 385664.151, 174428.610 38...
# found overlaps
#                                           properties
# 0  {'id': 89, 'included': 0, 'area': 2235, 'build...  \
#
#                                             geometry
# 0  POLYGON ((76868.086 434017.196, 76860.989 4340...
# found overlaps
#                                           properties
# 0  {'id': 90, 'included': 1, 'area': 10621, 'buil...  \
#
#                                             geometry
# 0  POLYGON ((205518.444 378102.742, 205517.617 37...
# found overlaps
#                                           properties
# 0  {'id': 91, 'included': 1, 'area': 2808, 'build...  \
#
#                                             geometry
# 0  POLYGON ((259428.161 480753.782, 259414.796 48...
# found overlaps
#                                           properties
# 0  {'id': 92, 'included': 1, 'area': 2435, 'build...  \
#
#                                             geometry
# 0  POLYGON ((184909.632 360861.148, 184911.878 36...
# found overlaps
#                                           properties
# 0  {'id': 93, 'included': 0, 'area': 1718, 'build...  \
#
#                                             geometry
# 0  POLYGON ((183017.883 332879.318, 183059.460 33...
# found overlaps
#                                           properties
# 0  {'id': 94, 'included': 1, 'area': 2646, 'build...  \
# 1  {'id': 95, 'included': 0, 'area': 24558, 'buil...
#
#                                             geometry
# 0  POLYGON ((191371.791 405660.538, 191388.942 40...
# 1  POLYGON ((191408.402 405822.000, 191444.584 40...
# found overlaps
#                                           properties
# 0  {'id': 96, 'included': 0, 'area': 4121, 'build...  \
#
#                                             geometry
# 0  MULTIPOLYGON (((123079.562 406551.848, 123077....
# found overlaps
#                                           properties
# 0  {'id': 97, 'included': 1, 'area': 4694, 'build...  \
#
#                                             geometry
# 0  MULTIPOLYGON (((112505.492 402398.323, 112508....
# found overlaps
#                                           properties
# 0  {'id': 98, 'included': 1, 'area': 8768, 'build...  \
# 1  {'id': 99, 'included': 1, 'area': 3530, 'build...
#
#                                             geometry
# 0  MULTIPOLYGON (((122378.978 502314.975, 122392....
# 1  POLYGON ((122461.692 502368.072, 122448.258 50...
# found overlaps
#                                           properties
# 0  {'id': 100, 'included': 1, 'area': 5647, 'buil...  \
#
#                                             geometry
# 0  POLYGON ((212041.360 462649.990, 212036.345 46...
# found overlaps
#                                           properties
# 0  {'id': 101, 'included': 0, 'area': 3385, 'buil...  \
#
#                                             geometry
# 0  POLYGON ((166001.741 448428.077, 165990.313 44...
# found overlaps
#                                           properties
# 0  {'id': 102, 'included': 1, 'area': 3901, 'buil...  \
#
#                                             geometry
# 0  POLYGON ((184289.611 332363.289, 184290.785 33...
# found overlaps
#                                           properties
# 0  {'id': 103, 'included': 1, 'area': 4664, 'buil...  \
#
#                                             geometry
# 0  POLYGON ((122074.709 490572.717, 122003.481 49...
# found overlaps
#                                           properties
# 0  {'id': 104, 'included': 0, 'area': 4121, 'buil...  \
#
#                                             geometry
# 0  MULTIPOLYGON (((123106.575 406567.017, 123104....
# found overlaps
#                                           properties
# 0  {'id': 105, 'included': 1, 'area': 3904, 'buil...  \
#
#                                             geometry
# 0  POLYGON ((166355.467 419606.158, 166355.735 41...
# found overlaps
#                                           properties
# 0  {'id': 106, 'included': 1, 'area': 14032, 'bui...  \
#
#                                             geometry
# 0  POLYGON ((199483.511 320072.668, 199465.766 32...
# found overlaps
#                                           properties
# 0  {'id': 107, 'included': 0, 'area': 1425, 'buil...  \
#
#                                             geometry
# 0  POLYGON ((195993.355 354879.120, 195985.018 35...
# found overlaps
#                                           properties
# 0  {'id': 108, 'included': 1, 'area': 3901, 'buil...  \
#
#                                             geometry
# 0  POLYGON ((184281.839 332415.450, 184289.321 33...
# done

# %%
### This script tests if all tiles have overlaps

files = os.listdir(big_tiles_folder)
names = [file.strip(".tif") for file in files if file.endswith(".tif")]

geojsons = os.listdir(json_folder)
for name in names:
    name_geojsons = [geojson for geojson in geojsons if name in geojson]
    print(name, "has", len(name_geojsons), "geojsons")

# %%
# # Pyhtonic version to check if the geojsons are correct:
# def split_annotations_to_geojson_pythonic (df, tiles_path, geojson_folder):
#     """
#     Split annotations data into the raster tiles and convert to the format of train-net.py: 
#     Pygeos to GPD to geojson.

#     Args:
#     df (GeoDataFrame): Vector dataset containing features to split.
#     tiles_path (str): Path to the directory where the raster tiles are stored
#     geojson_folder (str): Path to the directory where the output geojson files will be saved
    
#     Returns:
#     None
#     """
#     # Create spatial index for faster query
#     spatial_index = shapely.STRtree(df.geometry)
    
#     # Iterate through each raster tile
#     for tile in os.listdir(tiles_path):
#         if not tile.endswith('.tif'):
#             continue
        
#         input_file = os.path.join(tiles_path, tile)
#         with rasterio.open(input_file) as src:
#             geom = shapely.box(*src.bounds)
#             overlaps = spatial_index.query(geom, predicate='intersects')
        
#         # Create new geojson file for each overlapping geometry
#         if len(overlaps) > 0:
#             matches = df.iloc[overlaps]
#             exact_overlap = shapely.intersection(matches.geometry.values, geom)
            
#             objs = []
#             for polygon in exact_overlap:
#                 shapely_geom = shapely.to_shapely(polygon)
#                 objs.append({'properties': {'id': len(objs) + 1, 'building': 'yes'},
#                              'geometry': shapely_geom})
#             gdf = gpd.GeoDataFrame(objs, geometry='geometry', crs=src.crs)
#             img_id = tile.split(".tif")[0]
#             gdf.to_file(os.path.join(geojson_folder, f"{img_id}.geojson"), driver="GeoJSON")
