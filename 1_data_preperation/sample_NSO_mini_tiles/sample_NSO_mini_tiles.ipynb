# %%
import os

dir = "/scistor/ivm/jpl204/projects/detectron2-nso/NSO/geojsons"
out_file = "/scistor/ivm/jpl204/projects/detectron2-nso/1_data_preperation/sample_NSO_mini_tiles/NSO_mini_tiles_list.txt"

files = os.listdir(dir)
files = [filename.replace(".geojson", ".tif") for filename in files]

with open(out_file, 'w') as f:
    for file in files:
        f.write(file + '\n')

# %%
print (files)
# Out:
# ['143_20220811_110741_SV1-04_SV_RD_8bit_RGB_50cm_Biesbosch_11000_25000.tif', '145_20221101_105039_SV1-04_SV_RD_8bit_RGB_50cm_Venray_13000_21000.tif', '98_20220925_103904_SV2-01_SV_RD_8bit_RGB_50cm_Twello_24000_11000.tif', '88_20220719_105242_SV1-04_SV_RD_8bit_RGB_50cm_Eemshaven_25000_21000.tif', '76_20220718_111309_SV2-01_SV_RD_8bit_RGB_50cm_Spijkenisse_13000_37000.tif', '70_20221004_105549_SV2-01_SV_RD_8bit_RGB_50cm_Didam_19000_32000.tif', '48_20221004_105543_SV2-01_SV_RD_8bit_RGB_50cm_Haarle_11000_34000.tif', '122_20221215_105315_SV1-04_SV_RD_8bit_RGB_50cm_Assen_27000_11000.tif', '40_20221004_105524_SV2-01_SV_RD_8bit_RGB_50cm_Eemshaven_21000_14000.tif', '83_20230111_105203_SV1-04_SV_RD_8bit_RGB_50cm_Espel_18000_6000.tif', '59_20221102_105437_SV2-01_SV_RD_8bit_RGB_50cm_Echteld_7000_25000.tif', '140_20230111_105219_SV1-04_SV_RD_8bit_RGB_50cm_DenBosch_3000_13000.tif', '20_20220704_103620_SV2-01_SV_RD_8bit_RGB_50cm_Zuidlaren_15000_9000.tif', '70_20221004_105549_SV2-01_SV_RD_8bit_RGB_50
# ...
