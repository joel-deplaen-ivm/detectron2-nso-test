# %%
import os
import json
import yaml
import torch
import random
import detectron2

import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

from detectron2 import model_zoo
from detectron2.config import get_cfg
from detectron2.structures import BoxMode
from detectron2.engine import DefaultTrainer
from detectron2.engine import DefaultPredictor
from detectron2.utils.visualizer import ColorMode
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog, DatasetCatalog

# %%
#move def to utils

# Register the data set
def get_dataset_dicts(img_dir):
    json_file = os.path.join(img_dir, "via_region_data.json")
    with open(json_file) as f:
        imgs_anns = json.load(f)
    
    dataset_dicts = []
    for idx, annots in enumerate(imgs_anns.values()):
        record = {}
        
        filename = os.path.join(img_dir, annots["filename"])
        height, width = cv.imread(filename).shape[:2]
        
        #Info on the tile .png file
        record["file_name"] = filename
        record["image_id"] = idx
        record["height"] = height
        record["width"] = width
        
        #info on annotation
        annotations = annots["regions"]
        objs = []
        for _, anno in annotations.items():
            assert not anno["region_attributes"]
            anno = anno["shape_attributes"]
            px = anno["all_points_x"]
            py = anno["all_points_y"]
            poly = [(x + 0.5, y + 0.5) for x, y in zip(px, py)]
            poly = [p for x in poly for p in x]

            obj = {
                "bbox": [np.min(px),
                         np.min(py),
                         np.max(px),
                         np.max(py)
                        ],
                #XYXY_ABS: https://detectron2.readthedocs.io/en/latest/_modules/detectron2/structures/boxes.html
                "bbox_mode": BoxMode.XYXY_ABS,
                "segmentation": [poly],
                "category_id": anno["category"]
            }
            objs.append(obj)
        record["annotations"] = objs
        dataset_dicts.append(record)
    return dataset_dicts

classes = ["asset"]
colors = [(249, 180, 45)]

for d in ["train", "val"]:
    DatasetCatalog.register(d, lambda d=d: get_dataset_dicts(os.path.join("NSO", d)))
    MetadataCatalog.get(d).thing_classes = classes
    MetadataCatalog.get(d).thing_colors = colors
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Input In [15], in <cell line: 49>()
#      47 classes = ["asset"]
#      49 for d in ["train", "val"]:
# ---> 50     DatasetCatalog.register(d, lambda d=d: get_dataset_dicts(os.path.join("NSO", d)))
#      51     MetadataCatalog.get(d).thing_classes = classes
#
# File ~/miniconda3/envs/py38/lib/python3.8/site-packages/detectron2/data/catalog.py:37, in _DatasetCatalog.register(self, name, func)
#      30 """
#      31 Args:
#      32     name (str): the name that identifies a dataset, e.g. "coco_2014_train".
#      33     func (callable): a callable which takes no arguments and returns a list of dicts.
#      34         It must return the same results if called multiple times.
#      35 """
#      36 assert callable(func), "You must register a function with `DatasetCatalog.register`!"
# ---> 37 assert name not in self, "Dataset '{}' is already registered!".format(name)
#      38 self[name] = func
#
# AssertionError: Dataset 'train' is already registered!

# %%
# Check annotations on train set

metadata = MetadataCatalog.get("train")
dataset_dicts = get_dataset_dicts("NSO/train")

for d in random.sample(dataset_dicts, 3):
    img = cv.imread(d["file_name"])
    visualizer = Visualizer(img[:, :, ::-1], metadata=metadata, scale=1, instance_mode=ColorMode.IMAGE)
    out = visualizer.draw_dataset_dict(d)
    print(d["file_name"])
    plt.figure(figsize=(20, 20))
    plt.imshow(out.get_image()[:, :, ::-1])
    plt.show()
# Out:
# NSO/train/20706_11388.png
# NSO/train/20300_10950.png
# NSO/train/20706_10512.png

# %%
# Setting up model configugation for training

# obtain detectron2's default config
cfg = get_cfg()

# add custom component to configuration
# load values from a file
cfg.merge_from_file(model_zoo.get_config_file("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_1x.yaml"))
cfg.DATASETS.TRAIN = ("train",)
cfg.DATASETS.TEST = ("val",)
cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_1x.yaml")
cfg.SOLVER.BASE_LR = 0.0005
cfg.DATALOADER.NUM_WORKERS = 4
cfg.SOLVER.IMS_PER_BATCH = 4
cfg.MODEL.ROI_HEADS.BATCH_SIZE_PER_IMAGE = 16
cfg.MODEL.ROI_HEADS.NUM_CLASSES = len(classes)
cfg.OUTPUT_DIR = "NSO/output"
# print configs 
print(cfg.dump())  # print formatted configs

# Save your configurations for multi-GPU use
with open("NSO/NSOD2cfg.yaml", "w") as file:
    yaml.dump(cfg, file)

# %%
# Train
os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)
trainer = DefaultTrainer(cfg)
trainer.resume_or_load(resume=False)
trainer.train()
#Expect skip loading parameter because: The warning message is expected. Because your dataset has different number of classes from the pre-trained model, a few pre-trained weights have to be skipped.
# Out:
# [02/15 16:13:06 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (objectness_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
#   (roi_heads): StandardROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): FastRCNNConvFCHead(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#       (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc_relu1): ReLU()
#       (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#       (fc_relu2): ReLU()
#     )
#     (box_predictor): FastRCNNOutputLayers(
#       (cls_score): Linear(in_features=1024, out_features=2, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=4, bias=True)
#     )
#     (mask_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(14, 14), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(14, 14), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(14, 14), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(14, 14), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (mask_head): MaskRCNNConvUpsampleHead(
#       (mask_fcn1): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn2): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn3): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn4): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (deconv): ConvTranspose2d(256, 256, kernel_size=(2, 2), stride=(2, 2))
#       (deconv_relu): ReLU()
#       (predictor): Conv2d(256, 1, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
# )
# [02/15 16:13:06 d2.data.build]: Removed 0 images with no usable annotations. 4 images left.
# [02/15 16:13:06 d2.data.build]: Distribution of instances among all 1 categories:
# |  category  | #instances   |
# |:----------:|:-------------|
# |  building  | 4            |
# |            |              |
# [02/15 16:13:06 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(640, 672, 704, 736, 768, 800), max_size=1333, sample_style='choice'), RandomFlip()]
# [02/15 16:13:06 d2.data.build]: Using training sampler TrainingSampler
# [02/15 16:13:06 d2.data.common]: Serializing 4 elements to byte tensors and concatenating them all ...
# [02/15 16:13:06 d2.data.common]: Serialized dataset takes 0.00 MiB
# Skip loading parameter 'roi_heads.box_predictor.cls_score.weight' to the model due to incompatible shapes: (81, 1024) in the checkpoint but (2, 1024) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.cls_score.bias' to the model due to incompatible shapes: (81,) in the checkpoint but (2,) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.bbox_pred.weight' to the model due to incompatible shapes: (320, 1024) in the checkpoint but (4, 1024) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.bbox_pred.bias' to the model due to incompatible shapes: (320,) in the checkpoint but (4,) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.mask_head.predictor.weight' to the model due to incompatible shapes: (80, 256, 1, 1) in the checkpoint but (1, 256, 1, 1) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.mask_head.predictor.bias' to the model due to incompatible shapes: (80,) in the checkpoint but (1,) in the model! You might want to double check if this is expected.
# Some model parameters or buffers are not found in the checkpoint:
# roi_heads.box_predictor.bbox_pred.{bias, weight}
# roi_heads.box_predictor.cls_score.{bias, weight}
# roi_heads.mask_head.predictor.{bias, weight}
# [02/15 16:13:11 d2.engine.train_loop]: Starting training from iteration 0
# /scistor/ivm/jpl204/miniconda3/envs/py38/lib/python3.8/site-packages/detectron2/structures/image_list.py:88: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   max_size = (max_size + (stride - 1)) // stride * stride
# /scistor/ivm/jpl204/miniconda3/envs/py38/lib/python3.8/site-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# [02/15 16:13:15 d2.utils.events]:  eta: 1:49:53  iter: 19  total_loss: 1.699  loss_cls: 0.5631  loss_box_reg: 0.3508  loss_mask: 0.694  loss_rpn_cls: 0.05037  loss_rpn_loc: 0.006232  time: 0.0734  data_time: 0.0337  lr: 9.9905e-06  max_mem: 1161M
# [02/15 16:13:16 d2.utils.events]:  eta: 1:46:18  iter: 39  total_loss: 1.825  loss_cls: 0.5336  loss_box_reg: 0.5231  loss_mask: 0.6917  loss_rpn_cls: 0.04994  loss_rpn_loc: 0.00619  time: 0.0726  data_time: 0.0018  lr: 1.998e-05  max_mem: 1161M
# [02/15 16:13:18 d2.utils.events]:  eta: 1:52:45  iter: 59  total_loss: 1.833  loss_cls: 0.457  loss_box_reg: 0.6124  loss_mask: 0.6875  loss_rpn_cls: 0.03653  loss_rpn_loc: 0.005079  time: 0.0809  data_time: 0.0022  lr: 2.9971e-05  max_mem: 1161M
# [02/15 16:13:20 d2.utils.events]:  eta: 2:18:40  iter: 79  total_loss: 1.766  loss_cls: 0.4191  loss_box_reg: 0.583  loss_mask: 0.6812  loss_rpn_cls: 0.03516  loss_rpn_loc: 0.005834  time: 0.0853  data_time: 0.0022  lr: 3.9961e-05  max_mem: 1161M
# [02/15 16:13:22 d2.utils.events]:  eta: 2:21:32  iter: 99  total_loss: 1.853  loss_cls: 0.4011  loss_box_reg: 0.7724  loss_mask: 0.6721  loss_rpn_cls: 0.04639  loss_rpn_loc: 0.005213  time: 0.0878  data_time: 0.0022  lr: 4.9951e-05  max_mem: 1161M
# [02/15 16:13:24 d2.utils.events]:  eta: 2:21:22  iter: 119  total_loss: 1.976  loss_cls: 0.3516  loss_box_reg: 0.8613  loss_mask: 0.6612  loss_rpn_cls: 0.0303  loss_rpn_loc: 0.005183  time: 0.0874  data_time: 0.0021  lr: 5.994e-05  max_mem: 1161M
# [02/15 16:13:25 d2.utils.events]:  eta: 2:21:30  iter: 139  total_loss: 1.879  loss_cls: 0.3044  loss_box_reg: 0.8889  loss_mask: 0.6373  loss_rpn_cls: 0.0178  loss_rpn_loc: 0.00535  time: 0.0874  data_time: 0.0021  lr: 6.993e-05  max_mem: 1161M
# [02/15 16:13:27 d2.utils.events]:  eta: 2:22:06  iter: 159  total_loss: 1.735  loss_cls: 0.2592  loss_box_reg: 0.8521  loss_mask: 0.6039  loss_rpn_cls: 0.0107  loss_rpn_loc: 0.003672  time: 0.0886  data_time: 0.0022  lr: 7.992e-05  max_mem: 1161M
# [02/15 16:13:29 d2.utils.events]:  eta: 2:22:59  iter: 179  total_loss: 1.748  loss_cls: 0.2143  loss_box_reg: 0.8848  loss_mask: 0.5637  loss_rpn_cls: 0.005609  loss_rpn_loc: 0.003415  time: 0.0896  data_time: 0.0022  lr: 8.991e-05  max_mem: 1161M
# [02/15 16:13:31 d2.utils.events]:  eta: 2:21:33  iter: 199  total_loss: 1.554  loss_cls: 0.1591  loss_box_reg: 0.8593  loss_mask: 0.5306  loss_rpn_cls: 0.003749  loss_rpn_loc: 0.002851  time: 0.0876  data_time: 0.0019  lr: 9.9901e-05  max_mem: 1161M
# [02/15 16:13:32 d2.utils.events]:  eta: 2:20:07  iter: 219  total_loss: 1.472  loss_cls: 0.1194  loss_box_reg: 0.8192  loss_mask: 0.4325  loss_rpn_cls: 0.005699  loss_rpn_loc: 0.00248  time: 0.0861  data_time: 0.0019  lr: 0.00010989  max_mem: 1161M
# [02/15 16:13:34 d2.utils.events]:  eta: 2:17:19  iter: 239  total_loss: 1.196  loss_cls: 0.1442  loss_box_reg: 0.6753  loss_mask: 0.3515  loss_rpn_cls: 0.002057  loss_rpn_loc: 0.002988  time: 0.0850  data_time: 0.0019  lr: 0.00011988  max_mem: 1161M
# [02/15 16:13:35 d2.utils.events]:  eta: 1:53:09  iter: 259  total_loss: 0.9606  loss_cls: 0.1109  loss_box_reg: 0.5294  loss_mask: 0.3209  loss_rpn_cls: 0.0009383  loss_rpn_loc: 0.002634  time: 0.0842  data_time: 0.0026  lr: 0.00012987  max_mem: 1161M
# [02/15 16:13:37 d2.utils.events]:  eta: 1:52:36  iter: 279  total_loss: 0.7659  loss_cls: 0.05405  loss_box_reg: 0.4508  loss_mask: 0.2558  loss_rpn_cls: 0.0007545  loss_rpn_loc: 0.003513  time: 0.0832  data_time: 0.0019  lr: 0.00013986  max_mem: 1161M
# [02/15 16:13:38 d2.utils.events]:  eta: 1:52:19  iter: 299  total_loss: 0.6725  loss_cls: 0.04402  loss_box_reg: 0.3577  loss_mask: 0.2194  loss_rpn_cls: 0.0002648  loss_rpn_loc: 0.003142  time: 0.0825  data_time: 0.0020  lr: 0.00014985  max_mem: 1161M
# [02/15 16:13:40 d2.utils.events]:  eta: 1:52:08  iter: 319  total_loss: 0.5987  loss_cls: 0.05214  loss_box_reg: 0.3795  loss_mask: 0.1944  loss_rpn_cls: 5.168e-05  loss_rpn_loc: 0.002472  time: 0.0818  data_time: 0.0019  lr: 0.00015984  max_mem: 1161M
# [02/15 16:13:41 d2.utils.events]:  eta: 1:51:47  iter: 339  total_loss: 0.5692  loss_cls: 0.06155  loss_box_reg: 0.3351  loss_mask: 0.1715  loss_rpn_cls: 0.0001715  loss_rpn_loc: 0.002896  time: 0.0812  data_time: 0.0019  lr: 0.00016983  max_mem: 1161M
# [02/15 16:13:42 d2.utils.events]:  eta: 1:49:52  iter: 359  total_loss: 0.5966  loss_cls: 0.04945  loss_box_reg: 0.3154  loss_mask: 0.1701  loss_rpn_cls: 4.069e-05  loss_rpn_loc: 0.003258  time: 0.0806  data_time: 0.0019  lr: 0.00017982  max_mem: 1161M
# [02/15 16:13:44 d2.utils.events]:  eta: 1:49:36  iter: 379  total_loss: 0.5047  loss_cls: 0.0359  loss_box_reg: 0.3094  loss_mask: 0.151  loss_rpn_cls: 0.0003347  loss_rpn_loc: 0.002374  time: 0.0801  data_time: 0.0019  lr: 0.00018981  max_mem: 1161M
# [02/15 16:13:45 d2.utils.events]:  eta: 1:49:25  iter: 399  total_loss: 0.5882  loss_cls: 0.07727  loss_box_reg: 0.2764  loss_mask: 0.1303  loss_rpn_cls: 2.982e-05  loss_rpn_loc: 0.002103  time: 0.0796  data_time: 0.0019  lr: 0.0001998  max_mem: 1161M
# [02/15 16:13:47 d2.utils.events]:  eta: 1:49:17  iter: 419  total_loss: 0.4708  loss_cls: 0.05783  loss_box_reg: 0.2778  loss_mask: 0.1299  loss_rpn_cls: 5.078e-05  loss_rpn_loc: 0.001781  time: 0.0792  data_time: 0.0019  lr: 0.00020979  max_mem: 1161M
# [02/15 16:13:48 d2.utils.events]:  eta: 1:49:14  iter: 439  total_loss: 0.4444  loss_cls: 0.03036  loss_box_reg: 0.2622  loss_mask: 0.1255  loss_rpn_cls: 3.677e-05  loss_rpn_loc: 0.002304  time: 0.0789  data_time: 0.0019  lr: 0.00021978  max_mem: 1161M
# [02/15 16:13:50 d2.utils.events]:  eta: 1:49:05  iter: 459  total_loss: 0.4  loss_cls: 0.02741  loss_box_reg: 0.2423  loss_mask: 0.1006  loss_rpn_cls: 1.395e-05  loss_rpn_loc: 0.001656  time: 0.0785  data_time: 0.0019  lr: 0.00022977  max_mem: 1161M
# [02/15 16:13:51 d2.utils.events]:  eta: 1:49:01  iter: 479  total_loss: 0.4176  loss_cls: 0.04735  loss_box_reg: 0.2355  loss_mask: 0.1151  loss_rpn_cls: 4.906e-05  loss_rpn_loc: 0.002457  time: 0.0782  data_time: 0.0019  lr: 0.00023976  max_mem: 1161M
# [02/15 16:13:53 d2.utils.events]:  eta: 1:48:52  iter: 499  total_loss: 0.4362  loss_cls: 0.04278  loss_box_reg: 0.2502  loss_mask: 0.09716  loss_rpn_cls: 1.222e-05  loss_rpn_loc: 0.001948  time: 0.0779  data_time: 0.0019  lr: 0.00024975  max_mem: 1161M
# [02/15 16:13:54 d2.utils.events]:  eta: 1:48:46  iter: 519  total_loss: 0.4156  loss_cls: 0.01919  loss_box_reg: 0.2476  loss_mask: 0.1123  loss_rpn_cls: 3.24e-05  loss_rpn_loc: 0.001727  time: 0.0776  data_time: 0.0019  lr: 0.00025974  max_mem: 1161M
# [02/15 16:13:55 d2.utils.events]:  eta: 1:48:27  iter: 539  total_loss: 0.4043  loss_cls: 0.0436  loss_box_reg: 0.2549  loss_mask: 0.09668  loss_rpn_cls: 1.706e-05  loss_rpn_loc: 0.001401  time: 0.0774  data_time: 0.0019  lr: 0.00026973  max_mem: 1161M
# [02/15 16:13:57 d2.utils.events]:  eta: 1:48:05  iter: 559  total_loss: 0.408  loss_cls: 0.04891  loss_box_reg: 0.2593  loss_mask: 0.09306  loss_rpn_cls: 1.839e-05  loss_rpn_loc: 0.002019  time: 0.0772  data_time: 0.0019  lr: 0.00027972  max_mem: 1161M
# [02/15 16:13:58 d2.utils.events]:  eta: 1:47:41  iter: 579  total_loss: 0.3576  loss_cls: 0.02576  loss_box_reg: 0.2206  loss_mask: 0.08411  loss_rpn_cls: 3.466e-05  loss_rpn_loc: 0.001444  time: 0.0770  data_time: 0.0020  lr: 0.00028971  max_mem: 1161M
# [02/15 16:14:00 d2.utils.events]:  eta: 1:47:15  iter: 599  total_loss: 0.387  loss_cls: 0.03209  loss_box_reg: 0.2287  loss_mask: 0.08593  loss_rpn_cls: 1.46e-05  loss_rpn_loc: 0.001756  time: 0.0768  data_time: 0.0019  lr: 0.0002997  max_mem: 1161M
# [02/15 16:14:01 d2.utils.events]:  eta: 1:47:09  iter: 619  total_loss: 0.3442  loss_cls: 0.02581  loss_box_reg: 0.2243  loss_mask: 0.07857  loss_rpn_cls: 2.42e-05  loss_rpn_loc: 0.001691  time: 0.0766  data_time: 0.0019  lr: 0.00030969  max_mem: 1161M
# [02/15 16:14:03 d2.utils.events]:  eta: 1:47:02  iter: 639  total_loss: 0.3456  loss_cls: 0.02053  loss_box_reg: 0.219  loss_mask: 0.07455  loss_rpn_cls: 2.568e-05  loss_rpn_loc: 0.001576  time: 0.0764  data_time: 0.0019  lr: 0.00031968  max_mem: 1161M
# [02/15 16:14:04 d2.utils.events]:  eta: 1:47:01  iter: 659  total_loss: 0.3437  loss_cls: 0.01391  loss_box_reg: 0.2182  loss_mask: 0.07186  loss_rpn_cls: 3.098e-05  loss_rpn_loc: 0.001417  time: 0.0763  data_time: 0.0019  lr: 0.00032967  max_mem: 1161M
# [02/15 16:14:06 d2.utils.events]:  eta: 1:46:58  iter: 679  total_loss: 0.3536  loss_cls: 0.02546  loss_box_reg: 0.2496  loss_mask: 0.07378  loss_rpn_cls: 2.541e-05  loss_rpn_loc: 0.001145  time: 0.0761  data_time: 0.0019  lr: 0.00033966  max_mem: 1161M
# [02/15 16:14:07 d2.utils.events]:  eta: 1:46:54  iter: 699  total_loss: 0.3785  loss_cls: 0.03414  loss_box_reg: 0.2407  loss_mask: 0.07112  loss_rpn_cls: 1.621e-05  loss_rpn_loc: 0.001397  time: 0.0760  data_time: 0.0020  lr: 0.00034965  max_mem: 1161M
# [02/15 16:14:09 d2.utils.events]:  eta: 1:46:43  iter: 719  total_loss: 0.2984  loss_cls: 0.01735  loss_box_reg: 0.2069  loss_mask: 0.0704  loss_rpn_cls: 1.05e-05  loss_rpn_loc: 0.001316  time: 0.0759  data_time: 0.0019  lr: 0.00035964  max_mem: 1161M
# [02/15 16:14:10 d2.utils.events]:  eta: 1:46:34  iter: 739  total_loss: 0.3501  loss_cls: 0.01441  loss_box_reg: 0.2485  loss_mask: 0.06491  loss_rpn_cls: 2.012e-05  loss_rpn_loc: 0.000931  time: 0.0758  data_time: 0.0019  lr: 0.00036963  max_mem: 1161M
# [02/15 16:14:11 d2.utils.events]:  eta: 1:46:32  iter: 759  total_loss: 0.3332  loss_cls: 0.02976  loss_box_reg: 0.2228  loss_mask: 0.06639  loss_rpn_cls: 3.841e-05  loss_rpn_loc: 0.001533  time: 0.0757  data_time: 0.0019  lr: 0.00037962  max_mem: 1161M
# [02/15 16:14:13 d2.utils.events]:  eta: 1:46:27  iter: 779  total_loss: 0.3109  loss_cls: 0.01752  loss_box_reg: 0.192  loss_mask: 0.0657  loss_rpn_cls: 3.762e-05  loss_rpn_loc: 0.001246  time: 0.0755  data_time: 0.0019  lr: 0.00038961  max_mem: 1161M
# [02/15 16:14:14 d2.utils.events]:  eta: 1:46:24  iter: 799  total_loss: 0.2499  loss_cls: 0.01332  loss_box_reg: 0.1997  loss_mask: 0.05597  loss_rpn_cls: 3.009e-05  loss_rpn_loc: 0.001045  time: 0.0754  data_time: 0.0019  lr: 0.0003996  max_mem: 1161M
# [02/15 16:14:16 d2.utils.events]:  eta: 1:46:22  iter: 819  total_loss: 0.3484  loss_cls: 0.01644  loss_box_reg: 0.2149  loss_mask: 0.05511  loss_rpn_cls: 4.104e-05  loss_rpn_loc: 0.001285  time: 0.0753  data_time: 0.0019  lr: 0.00040959  max_mem: 1161M
# [02/15 16:14:17 d2.utils.events]:  eta: 1:46:21  iter: 839  total_loss: 0.347  loss_cls: 0.02609  loss_box_reg: 0.2106  loss_mask: 0.05066  loss_rpn_cls: 2.139e-05  loss_rpn_loc: 0.001172  time: 0.0752  data_time: 0.0019  lr: 0.00041958  max_mem: 1161M
# [02/15 16:14:19 d2.utils.events]:  eta: 1:46:19  iter: 859  total_loss: 0.3254  loss_cls: 0.02218  loss_box_reg: 0.2484  loss_mask: 0.05429  loss_rpn_cls: 5.357e-05  loss_rpn_loc: 0.00154  time: 0.0752  data_time: 0.0019  lr: 0.00042957  max_mem: 1161M
# [02/15 16:14:20 d2.utils.events]:  eta: 1:46:18  iter: 879  total_loss: 0.3403  loss_cls: 0.01613  loss_box_reg: 0.2357  loss_mask: 0.05318  loss_rpn_cls: 5.259e-05  loss_rpn_loc: 0.001661  time: 0.0751  data_time: 0.0019  lr: 0.00043956  max_mem: 1161M
# [02/15 16:14:22 d2.utils.events]:  eta: 1:46:15  iter: 899  total_loss: 0.308  loss_cls: 0.01272  loss_box_reg: 0.2093  loss_mask: 0.04972  loss_rpn_cls: 1.539e-05  loss_rpn_loc: 0.00101  time: 0.0750  data_time: 0.0019  lr: 0.00044955  max_mem: 1161M
# [02/15 16:14:23 d2.utils.events]:  eta: 1:46:12  iter: 919  total_loss: 0.283  loss_cls: 0.01655  loss_box_reg: 0.1825  loss_mask: 0.05374  loss_rpn_cls: 4.667e-05  loss_rpn_loc: 0.001201  time: 0.0749  data_time: 0.0019  lr: 0.00045954  max_mem: 1161M
# [02/15 16:14:24 d2.utils.events]:  eta: 1:46:11  iter: 939  total_loss: 0.3011  loss_cls: 0.02378  loss_box_reg: 0.1961  loss_mask: 0.05006  loss_rpn_cls: 5.842e-05  loss_rpn_loc: 0.001022  time: 0.0748  data_time: 0.0019  lr: 0.00046953  max_mem: 1161M
# [02/15 16:14:26 d2.utils.events]:  eta: 1:46:09  iter: 959  total_loss: 0.3153  loss_cls: 0.02241  loss_box_reg: 0.1789  loss_mask: 0.05177  loss_rpn_cls: 4.336e-05  loss_rpn_loc: 0.001229  time: 0.0747  data_time: 0.0019  lr: 0.00047952  max_mem: 1161M
# [02/15 16:14:27 d2.utils.events]:  eta: 1:46:08  iter: 979  total_loss: 0.295  loss_cls: 0.02619  loss_box_reg: 0.2028  loss_mask: 0.05239  loss_rpn_cls: 1.694e-05  loss_rpn_loc: 0.0008976  time: 0.0747  data_time: 0.0019  lr: 0.00048951  max_mem: 1161M
# [02/15 16:14:29 d2.utils.events]:  eta: 1:46:06  iter: 999  total_loss: 0.3012  loss_cls: 0.03272  loss_box_reg: 0.2145  loss_mask: 0.04018  loss_rpn_cls: 3.006e-05  loss_rpn_loc: 0.0008915  time: 0.0746  data_time: 0.0019  lr: 0.0004995  max_mem: 1161M
# [02/15 16:14:30 d2.utils.events]:  eta: 1:46:05  iter: 1019  total_loss: 0.3196  loss_cls: 0.01907  loss_box_reg: 0.2372  loss_mask: 0.05345  loss_rpn_cls: 7.16e-05  loss_rpn_loc: 0.0008833  time: 0.0746  data_time: 0.0020  lr: 0.0005  max_mem: 1161M
# [02/15 16:14:32 d2.utils.events]:  eta: 1:46:03  iter: 1039  total_loss: 0.3366  loss_cls: 0.04173  loss_box_reg: 0.206  loss_mask: 0.05176  loss_rpn_cls: 4.711e-05  loss_rpn_loc: 0.00096  time: 0.0745  data_time: 0.0019  lr: 0.0005  max_mem: 1161M
# [02/15 16:14:33 d2.utils.events]:  eta: 1:46:00  iter: 1059  total_loss: 0.2855  loss_cls: 0.03246  loss_box_reg: 0.2088  loss_mask: 0.05277  loss_rpn_cls: 5.84e-05  loss_rpn_loc: 0.0008293  time: 0.0744  data_time: 0.0019  lr: 0.0005  max_mem: 1161M
# [02/15 16:14:35 d2.utils.events]:  eta: 1:45:57  iter: 1079  total_loss: 0.2858  loss_cls: 0.03038  loss_box_reg: 0.2172  loss_mask: 0.04913  loss_rpn_cls: 0.0001879  loss_rpn_loc: 0.001544  time: 0.0744  data_time: 0.0019  lr: 0.0005  max_mem: 1161M
# [02/15 16:14:36 d2.utils.events]:  eta: 1:45:53  iter: 1099  total_loss: 0.2841  loss_cls: 0.02043  loss_box_reg: 0.2085  loss_mask: 0.041  loss_rpn_cls: 0.0001223  loss_rpn_loc: 0.0009827  time: 0.0743  data_time: 0.0019  lr: 0.0005  max_mem: 1161M
# [02/15 16:14:38 d2.utils.events]:  eta: 1:45:51  iter: 1119  total_loss: 0.2599  loss_cls: 0.02336  loss_box_reg: 0.1717  loss_mask: 0.03945  loss_rpn_cls: 4.188e-05  loss_rpn_loc: 0.0009516  time: 0.0743  data_time: 0.0020  lr: 0.0005  max_mem: 1161M
# [02/15 16:14:39 d2.utils.events]:  eta: 1:45:48  iter: 1139  total_loss: 0.2753  loss_cls: 0.01718  loss_box_reg: 0.1824  loss_mask: 0.04246  loss_rpn_cls: 5.041e-05  loss_rpn_loc: 0.001459  time: 0.0743  data_time: 0.0020  lr: 0.0005  max_mem: 1161M
# [02/15 16:14:41 d2.utils.events]:  eta: 1:45:44  iter: 1159  total_loss: 0.2527  loss_cls: 0.01698  loss_box_reg: 0.1848  loss_mask: 0.04031  loss_rpn_cls: 0.0001087  loss_rpn_loc: 0.001055  time: 0.0743  data_time: 0.0019  lr: 0.0005  max_mem: 1161M
# [02/15 16:14:42 d2.utils.events]:  eta: 1:45:39  iter: 1179  total_loss: 0.3083  loss_cls: 0.01403  loss_box_reg: 0.211  loss_mask: 0.0387  loss_rpn_cls: 9.463e-05  loss_rpn_loc: 0.001003  time: 0.0742  data_time: 0.0019  lr: 0.0005  max_mem: 1161M
# [02/15 16:14:43 d2.utils.events]:  eta: 1:45:40  iter: 1199  total_loss: 0.2606  loss_cls: 0.01366  loss_box_reg: 0.1951  loss_mask: 0.03927  loss_rpn_cls: 8.189e-05  loss_rpn_loc: 0.0009429  time: 0.0742  data_time: 0.0020  lr: 0.0005  max_mem: 1161M
# [02/15 16:14:45 d2.utils.events]:  eta: 1:45:37  iter: 1219  total_loss: 0.291  loss_cls: 0.01647  loss_box_reg: 0.1827  loss_mask: 0.03933  loss_rpn_cls: 8.548e-05  loss_rpn_loc: 0.0006659  time: 0.0741  data_time: 0.0019  lr: 0.0005  max_mem: 1161M
# [02/15 16:14:46 d2.utils.events]:  eta: 1:45:35  iter: 1239  total_loss: 0.2629  loss_cls: 0.02326  loss_box_reg: 0.1803  loss_mask: 0.0388  loss_rpn_cls: 7.534e-05  loss_rpn_loc: 0.0009005  time: 0.0741  data_time: 0.0019  lr: 0.0005  max_mem: 1161M
# [02/15 16:14:48 d2.utils.events]:  eta: 1:45:33  iter: 1259  total_loss: 0.2753  loss_cls: 0.02309  loss_box_reg: 0.1778  loss_mask: 0.0337  loss_rpn_cls: 3.997e-05  loss_rpn_loc: 0.0006899  time: 0.0740  data_time: 0.0019  lr: 0.0005  max_mem: 1161M
# [02/15 16:14:49 d2.utils.events]:  eta: 1:45:31  iter: 1279  total_loss: 0.3419  loss_cls: 0.02744  loss_box_reg: 0.2341  loss_mask: 0.0401  loss_rpn_cls: 6.007e-05  loss_rpn_loc: 0.001092  time: 0.0740  data_time: 0.0019  lr: 0.0005  max_mem: 1161M
# [02/15 16:14:51 d2.utils.events]:  eta: 1:45:28  iter: 1299  total_loss: 0.2586  loss_cls: 0.01289  loss_box_reg: 0.1686  loss_mask: 0.04145  loss_rpn_cls: 6.365e-05  loss_rpn_loc: 0.000993  time: 0.0740  data_time: 0.0019  lr: 0.0005  max_mem: 1161M
# [02/15 16:14:52 d2.utils.events]:  eta: 1:45:27  iter: 1319  total_loss: 0.3067  loss_cls: 0.02609  loss_box_reg: 0.2057  loss_mask: 0.04395  loss_rpn_cls: 4.766e-05  loss_rpn_loc: 0.00105  time: 0.0739  data_time: 0.0019  lr: 0.0005  max_mem: 1161M
# [02/15 16:14:54 d2.utils.events]:  eta: 1:45:25  iter: 1339  total_loss: 0.2356  loss_cls: 0.01487  loss_box_reg: 0.1588  loss_mask: 0.035  loss_rpn_cls: 9.149e-05  loss_rpn_loc: 0.001037  time: 0.0739  data_time: 0.0019  lr: 0.0005  max_mem: 1161M
# [02/15 16:14:55 d2.utils.events]:  eta: 1:45:24  iter: 1359  total_loss: 0.2629  loss_cls: 0.0356  loss_box_reg: 0.1835  loss_mask: 0.03728  loss_rpn_cls: 4.347e-05  loss_rpn_loc: 0.0008538  time: 0.0739  data_time: 0.0019  lr: 0.0005  max_mem: 1161M
# [02/15 16:14:57 d2.utils.events]:  eta: 1:45:23  iter: 1379  total_loss: 0.2107  loss_cls: 0.01187  loss_box_reg: 0.1562  loss_mask: 0.03658  loss_rpn_cls: 0.000122  loss_rpn_loc: 0.0009707  time: 0.0738  data_time: 0.0019  lr: 0.0005  max_mem: 1161M
# [02/15 16:14:58 d2.utils.events]:  eta: 1:45:21  iter: 1399  total_loss: 0.2475  loss_cls: 0.01942  loss_box_reg: 0.1672  loss_mask: 0.03719  loss_rpn_cls: 0.0001201  loss_rpn_loc: 0.0009729  time: 0.0738  data_time: 0.0019  lr: 0.0005  max_mem: 1161M
# [02/15 16:14:59 d2.utils.events]:  eta: 1:45:20  iter: 1419  total_loss: 0.2428  loss_cls: 0.01221  loss_box_reg: 0.1731  loss_mask: 0.03469  loss_rpn_cls: 6.558e-05  loss_rpn_loc: 0.001305  time: 0.0737  data_time: 0.0019  lr: 0.0005  max_mem: 1161M
# [02/15 16:15:01 d2.utils.events]:  eta: 1:45:18  iter: 1439  total_loss: 0.267  loss_cls: 0.02594  loss_box_reg: 0.1969  loss_mask: 0.03425  loss_rpn_cls: 8.215e-05  loss_rpn_loc: 0.0009332  time: 0.0737  data_time: 0.0019  lr: 0.0005  max_mem: 1161M
# [02/15 16:15:02 d2.utils.events]:  eta: 1:45:17  iter: 1459  total_loss: 0.2234  loss_cls: 0.01279  loss_box_reg: 0.1539  loss_mask: 0.03041  loss_rpn_cls: 8.873e-05  loss_rpn_loc: 0.000657  time: 0.0737  data_time: 0.0020  lr: 0.0005  max_mem: 1161M
# [02/15 16:15:04 d2.utils.events]:  eta: 1:45:15  iter: 1479  total_loss: 0.2258  loss_cls: 0.008046  loss_box_reg: 0.1633  loss_mask: 0.03007  loss_rpn_cls: 7.351e-05  loss_rpn_loc: 0.0007405  time: 0.0737  data_time: 0.0020  lr: 0.0005  max_mem: 1161M
# [02/15 16:15:05 d2.utils.events]:  eta: 1:45:14  iter: 1499  total_loss: 0.2333  loss_cls: 0.0259  loss_box_reg: 0.159  loss_mask: 0.03786  loss_rpn_cls: 0.0001032  loss_rpn_loc: 0.0007829  time: 0.0736  data_time: 0.0019  lr: 0.0005  max_mem: 1161M
# [02/15 16:15:07 d2.utils.events]:  eta: 1:45:14  iter: 1519  total_loss: 0.2571  loss_cls: 0.01833  loss_box_reg: 0.1858  loss_mask: 0.03669  loss_rpn_cls: 0.0001383  loss_rpn_loc: 0.001275  time: 0.0736  data_time: 0.0020  lr: 0.0005  max_mem: 1161M
# [02/15 16:15:08 d2.utils.events]:  eta: 1:45:12  iter: 1539  total_loss: 0.231  loss_cls: 0.02238  loss_box_reg: 0.1439  loss_mask: 0.03179  loss_rpn_cls: 0.0001135  loss_rpn_loc: 0.0008358  time: 0.0736  data_time: 0.0019  lr: 0.0005  max_mem: 1161M
# [02/15 16:15:10 d2.utils.events]:  eta: 1:45:11  iter: 1559  total_loss: 0.2182  loss_cls: 0.01844  loss_box_reg: 0.1585  loss_mask: 0.0348  loss_rpn_cls: 0.0001001  loss_rpn_loc: 0.0006813  time: 0.0736  data_time: 0.0019  lr: 0.0005  max_mem: 1161M
# [02/15 16:15:11 d2.utils.events]:  eta: 1:45:09  iter: 1579  total_loss: 0.2231  loss_cls: 0.0223  loss_box_reg: 0.1662  loss_mask: 0.03173  loss_rpn_cls: 7.223e-05  loss_rpn_loc: 0.0007949  time: 0.0735  data_time: 0.0019  lr: 0.0005  max_mem: 1161M
# [02/15 16:15:13 d2.utils.events]:  eta: 1:45:08  iter: 1599  total_loss: 0.2354  loss_cls: 0.01989  loss_box_reg: 0.1733  loss_mask: 0.03312  loss_rpn_cls: 8.119e-05  loss_rpn_loc: 0.000796  time: 0.0735  data_time: 0.0019  lr: 0.0005  max_mem: 1161M
# [02/15 16:15:14 d2.utils.events]:  eta: 1:45:05  iter: 1619  total_loss: 0.2063  loss_cls: 0.01184  loss_box_reg: 0.16  loss_mask: 0.03153  loss_rpn_cls: 0.0001116  loss_rpn_loc: 0.0007685  time: 0.0735  data_time: 0.0019  lr: 0.0005  max_mem: 1161M
# [02/15 16:15:15 d2.utils.events]:  eta: 1:45:04  iter: 1639  total_loss: 0.2095  loss_cls: 0.007834  loss_box_reg: 0.1593  loss_mask: 0.0323  loss_rpn_cls: 5.527e-05  loss_rpn_loc: 0.0006228  time: 0.0735  data_time: 0.0019  lr: 0.0005  max_mem: 1161M
# [02/15 16:15:17 d2.utils.events]:  eta: 1:45:02  iter: 1659  total_loss: 0.2531  loss_cls: 0.01098  loss_box_reg: 0.1837  loss_mask: 0.0307  loss_rpn_cls: 8.87e-05  loss_rpn_loc: 0.001009  time: 0.0734  data_time: 0.0019  lr: 0.0005  max_mem: 1161M
# [02/15 16:15:18 d2.utils.events]:  eta: 1:45:02  iter: 1679  total_loss: 0.2584  loss_cls: 0.01517  loss_box_reg: 0.2021  loss_mask: 0.03115  loss_rpn_cls: 7.209e-05  loss_rpn_loc: 0.0007635  time: 0.0734  data_time: 0.0020  lr: 0.0005  max_mem: 1161M
# [02/15 16:15:20 d2.utils.events]:  eta: 1:45:02  iter: 1699  total_loss: 0.2222  loss_cls: 0.02787  loss_box_reg: 0.1697  loss_mask: 0.03053  loss_rpn_cls: 0.0001307  loss_rpn_loc: 0.0009493  time: 0.0735  data_time: 0.0020  lr: 0.0005  max_mem: 1161M
# [02/15 16:15:21 d2.utils.events]:  eta: 1:45:02  iter: 1719  total_loss: 0.2624  loss_cls: 0.01993  loss_box_reg: 0.1756  loss_mask: 0.03217  loss_rpn_cls: 7.679e-05  loss_rpn_loc: 0.0008677  time: 0.0735  data_time: 0.0020  lr: 0.0005  max_mem: 1161M
# [02/15 16:15:23 d2.utils.events]:  eta: 1:45:03  iter: 1739  total_loss: 0.2154  loss_cls: 0.007412  loss_box_reg: 0.1669  loss_mask: 0.03453  loss_rpn_cls: 0.0001332  loss_rpn_loc: 0.0007879  time: 0.0734  data_time: 0.0020  lr: 0.0005  max_mem: 1161M
# [02/15 16:15:24 d2.utils.events]:  eta: 1:45:03  iter: 1759  total_loss: 0.2426  loss_cls: 0.01322  loss_box_reg: 0.1863  loss_mask: 0.03308  loss_rpn_cls: 0.0001044  loss_rpn_loc: 0.000593  time: 0.0734  data_time: 0.0020  lr: 0.0005  max_mem: 1161M
# [02/15 16:15:26 d2.utils.events]:  eta: 1:45:03  iter: 1779  total_loss: 0.1978  loss_cls: 0.0102  loss_box_reg: 0.1392  loss_mask: 0.03133  loss_rpn_cls: 9.61e-05  loss_rpn_loc: 0.0007168  time: 0.0734  data_time: 0.0020  lr: 0.0005  max_mem: 1161M
# [02/15 16:15:27 d2.utils.events]:  eta: 1:45:04  iter: 1799  total_loss: 0.206  loss_cls: 0.01005  loss_box_reg: 0.1405  loss_mask: 0.02671  loss_rpn_cls: 5.374e-05  loss_rpn_loc: 0.0008977  time: 0.0734  data_time: 0.0020  lr: 0.0005  max_mem: 1161M
# [02/15 16:15:29 d2.utils.events]:  eta: 1:45:04  iter: 1819  total_loss: 0.2331  loss_cls: 0.009406  loss_box_reg: 0.1646  loss_mask: 0.03326  loss_rpn_cls: 0.000146  loss_rpn_loc: 0.000658  time: 0.0734  data_time: 0.0020  lr: 0.0005  max_mem: 1161M
# [02/15 16:15:30 d2.utils.events]:  eta: 1:45:02  iter: 1839  total_loss: 0.1998  loss_cls: 0.01273  loss_box_reg: 0.1417  loss_mask: 0.02882  loss_rpn_cls: 8.242e-05  loss_rpn_loc: 0.0007147  time: 0.0734  data_time: 0.0020  lr: 0.0005  max_mem: 1161M
# [02/15 16:15:32 d2.utils.events]:  eta: 1:45:01  iter: 1859  total_loss: 0.2125  loss_cls: 0.01173  loss_box_reg: 0.1398  loss_mask: 0.0261  loss_rpn_cls: 8.593e-05  loss_rpn_loc: 0.0006604  time: 0.0734  data_time: 0.0020  lr: 0.0005  max_mem: 1161M
# [02/15 16:15:33 d2.utils.events]:  eta: 1:45:00  iter: 1879  total_loss: 0.2213  loss_cls: 0.01541  loss_box_reg: 0.1598  loss_mask: 0.02715  loss_rpn_cls: 0.0001451  loss_rpn_loc: 0.001  time: 0.0734  data_time: 0.0020  lr: 0.0005  max_mem: 1161M
# [02/15 16:15:35 d2.utils.events]:  eta: 1:44:59  iter: 1899  total_loss: 0.1995  loss_cls: 0.009718  loss_box_reg: 0.1298  loss_mask: 0.02911  loss_rpn_cls: 9.239e-05  loss_rpn_loc: 0.000717  time: 0.0734  data_time: 0.0020  lr: 0.0005  max_mem: 1161M
# [02/15 16:15:37 d2.utils.events]:  eta: 1:45:01  iter: 1919  total_loss: 0.196  loss_cls: 0.01047  loss_box_reg: 0.1337  loss_mask: 0.02532  loss_rpn_cls: 0.0001257  loss_rpn_loc: 0.0005852  time: 0.0736  data_time: 0.0022  lr: 0.0005  max_mem: 1161M
# [02/15 16:15:38 d2.utils.events]:  eta: 1:45:00  iter: 1939  total_loss: 0.1829  loss_cls: 0.01037  loss_box_reg: 0.1196  loss_mask: 0.02757  loss_rpn_cls: 7.951e-05  loss_rpn_loc: 0.0006192  time: 0.0736  data_time: 0.0020  lr: 0.0005  max_mem: 1161M
# [02/15 16:15:40 d2.utils.events]:  eta: 1:44:58  iter: 1959  total_loss: 0.1888  loss_cls: 0.008533  loss_box_reg: 0.1383  loss_mask: 0.027  loss_rpn_cls: 0.0001402  loss_rpn_loc: 0.0006822  time: 0.0736  data_time: 0.0020  lr: 0.0005  max_mem: 1161M
# [02/15 16:15:41 d2.utils.events]:  eta: 1:44:59  iter: 1979  total_loss: 0.1943  loss_cls: 0.01039  loss_box_reg: 0.1294  loss_mask: 0.02772  loss_rpn_cls: 9.627e-05  loss_rpn_loc: 0.0005937  time: 0.0736  data_time: 0.0020  lr: 0.0005  max_mem: 1161M
# [02/15 16:15:43 d2.utils.events]:  eta: 1:44:56  iter: 1999  total_loss: 0.2063  loss_cls: 0.01013  loss_box_reg: 0.1478  loss_mask: 0.02407  loss_rpn_cls: 0.0001377  loss_rpn_loc: 0.0008042  time: 0.0736  data_time: 0.0020  lr: 0.0005  max_mem: 1161M
# [02/15 16:15:44 d2.utils.events]:  eta: 1:44:54  iter: 2019  total_loss: 0.2135  loss_cls: 0.01126  loss_box_reg: 0.1472  loss_mask: 0.03181  loss_rpn_cls: 9.839e-05  loss_rpn_loc: 0.0005811  time: 0.0736  data_time: 0.0020  lr: 0.0005  max_mem: 1161M
# [02/15 16:15:46 d2.utils.events]:  eta: 1:44:55  iter: 2039  total_loss: 0.2034  loss_cls: 0.006851  loss_box_reg: 0.1489  loss_mask: 0.02951  loss_rpn_cls: 0.0001026  loss_rpn_loc: 0.0005087  time: 0.0736  data_time: 0.0020  lr: 0.0005  max_mem: 1161M
# [02/15 16:15:47 d2.utils.events]:  eta: 1:44:54  iter: 2059  total_loss: 0.1916  loss_cls: 0.01158  loss_box_reg: 0.1461  loss_mask: 0.02747  loss_rpn_cls: 7.891e-05  loss_rpn_loc: 0.000871  time: 0.0735  data_time: 0.0020  lr: 0.0005  max_mem: 1161M
# [02/15 16:15:48 d2.utils.events]:  eta: 1:44:52  iter: 2079  total_loss: 0.2061  loss_cls: 0.01325  loss_box_reg: 0.149  loss_mask: 0.02446  loss_rpn_cls: 0.0001594  loss_rpn_loc: 0.001009  time: 0.0735  data_time: 0.0019  lr: 0.0005  max_mem: 1161M
# [02/15 16:15:50 d2.utils.events]:  eta: 1:44:48  iter: 2099  total_loss: 0.2114  loss_cls: 0.01012  loss_box_reg: 0.153  loss_mask: 0.02714  loss_rpn_cls: 0.0001139  loss_rpn_loc: 0.0007551  time: 0.0735  data_time: 0.0020  lr: 0.0005  max_mem: 1161M
# [02/15 16:15:51 d2.utils.events]:  eta: 1:44:44  iter: 2119  total_loss: 0.1999  loss_cls: 0.01622  loss_box_reg: 0.1366  loss_mask: 0.02432  loss_rpn_cls: 0.0001447  loss_rpn_loc: 0.0006238  time: 0.0735  data_time: 0.0020  lr: 0.0005  max_mem: 1161M
# [02/15 16:15:53 d2.utils.events]:  eta: 1:44:42  iter: 2139  total_loss: 0.1873  loss_cls: 0.007502  loss_box_reg: 0.1411  loss_mask: 0.02722  loss_rpn_cls: 0.0001247  loss_rpn_loc: 0.0009956  time: 0.0735  data_time: 0.0020  lr: 0.0005  max_mem: 1161M
# [02/15 16:15:55 d2.utils.events]:  eta: 1:44:44  iter: 2159  total_loss: 0.1848  loss_cls: 0.007952  loss_box_reg: 0.1476  loss_mask: 0.02516  loss_rpn_cls: 0.0001735  loss_rpn_loc: 0.0006742  time: 0.0737  data_time: 0.0022  lr: 0.0005  max_mem: 1161M
# [02/15 16:15:56 d2.utils.events]:  eta: 1:44:46  iter: 2179  total_loss: 0.189  loss_cls: 0.009206  loss_box_reg: 0.1328  loss_mask: 0.02556  loss_rpn_cls: 0.0001616  loss_rpn_loc: 0.0008757  time: 0.0738  data_time: 0.0021  lr: 0.0005  max_mem: 1161M
# [02/15 16:15:58 d2.utils.events]:  eta: 1:44:46  iter: 2199  total_loss: 0.2135  loss_cls: 0.01495  loss_box_reg: 0.1417  loss_mask: 0.02702  loss_rpn_cls: 0.0002094  loss_rpn_loc: 0.0006554  time: 0.0740  data_time: 0.0023  lr: 0.0005  max_mem: 1161M
# [02/15 16:16:00 d2.utils.events]:  eta: 1:44:50  iter: 2219  total_loss: 0.2225  loss_cls: 0.02156  loss_box_reg: 0.147  loss_mask: 0.02392  loss_rpn_cls: 0.0001501  loss_rpn_loc: 0.0008286  time: 0.0742  data_time: 0.0023  lr: 0.0005  max_mem: 1161M
# [02/15 16:16:02 d2.utils.events]:  eta: 1:44:57  iter: 2239  total_loss: 0.1691  loss_cls: 0.01213  loss_box_reg: 0.1195  loss_mask: 0.02393  loss_rpn_cls: 0.0001215  loss_rpn_loc: 0.0006511  time: 0.0744  data_time: 0.0023  lr: 0.0005  max_mem: 1161M
# [02/15 16:16:04 d2.utils.events]:  eta: 1:44:54  iter: 2259  total_loss: 0.1874  loss_cls: 0.01633  loss_box_reg: 0.1271  loss_mask: 0.02856  loss_rpn_cls: 0.000204  loss_rpn_loc: 0.0005987  time: 0.0743  data_time: 0.0020  lr: 0.0005  max_mem: 1161M
# [02/15 16:16:05 d2.utils.events]:  eta: 1:44:55  iter: 2279  total_loss: 0.1886  loss_cls: 0.00718  loss_box_reg: 0.1378  loss_mask: 0.02839  loss_rpn_cls: 0.0001177  loss_rpn_loc: 0.0004473  time: 0.0743  data_time: 0.0020  lr: 0.0005  max_mem: 1161M
# [02/15 16:16:07 d2.utils.events]:  eta: 1:44:55  iter: 2299  total_loss: 0.1917  loss_cls: 0.01822  loss_box_reg: 0.1281  loss_mask: 0.02729  loss_rpn_cls: 0.0001733  loss_rpn_loc: 0.0006091  time: 0.0743  data_time: 0.0020  lr: 0.0005  max_mem: 1161M
# [02/15 16:16:08 d2.utils.events]:  eta: 1:44:51  iter: 2319  total_loss: 0.1612  loss_cls: 0.005089  loss_box_reg: 0.1252  loss_mask: 0.02262  loss_rpn_cls: 0.0001709  loss_rpn_loc: 0.0006068  time: 0.0743  data_time: 0.0020  lr: 0.0005  max_mem: 1161M
# [02/15 16:16:10 d2.utils.events]:  eta: 1:44:51  iter: 2339  total_loss: 0.1874  loss_cls: 0.009166  loss_box_reg: 0.1334  loss_mask: 0.02353  loss_rpn_cls: 0.0001307  loss_rpn_loc: 0.0007293  time: 0.0742  data_time: 0.0020  lr: 0.0005  max_mem: 1161M
# [02/15 16:16:11 d2.utils.events]:  eta: 1:44:49  iter: 2359  total_loss: 0.2163  loss_cls: 0.01897  loss_box_reg: 0.1705  loss_mask: 0.02503  loss_rpn_cls: 0.0001874  loss_rpn_loc: 0.0006537  time: 0.0742  data_time: 0.0019  lr: 0.0005  max_mem: 1161M
# [02/15 16:16:12 d2.utils.events]:  eta: 1:44:52  iter: 2379  total_loss: 0.2186  loss_cls: 0.007194  loss_box_reg: 0.1556  loss_mask: 0.02522  loss_rpn_cls: 0.0001524  loss_rpn_loc: 0.0004626  time: 0.0742  data_time: 0.0020  lr: 0.0005  max_mem: 1161M
# [02/15 16:16:14 d2.utils.events]:  eta: 1:44:55  iter: 2399  total_loss: 0.2149  loss_cls: 0.01003  loss_box_reg: 0.1543  loss_mask: 0.02538  loss_rpn_cls: 0.0001931  loss_rpn_loc: 0.000659  time: 0.0742  data_time: 0.0020  lr: 0.0005  max_mem: 1161M
# [02/15 16:16:15 d2.utils.events]:  eta: 1:44:50  iter: 2419  total_loss: 0.1916  loss_cls: 0.009707  loss_box_reg: 0.1534  loss_mask: 0.02442  loss_rpn_cls: 0.000146  loss_rpn_loc: 0.0007873  time: 0.0741  data_time: 0.0020  lr: 0.0005  max_mem: 1161M
# [02/15 16:16:17 d2.utils.events]:  eta: 1:44:43  iter: 2439  total_loss: 0.1943  loss_cls: 0.009672  loss_box_reg: 0.1378  loss_mask: 0.0243  loss_rpn_cls: 0.0001873  loss_rpn_loc: 0.0008387  time: 0.0741  data_time: 0.0019  lr: 0.0005  max_mem: 1161M
# [02/15 16:16:18 d2.utils.events]:  eta: 1:44:42  iter: 2459  total_loss: 0.1787  loss_cls: 0.004805  loss_box_reg: 0.1331  loss_mask: 0.02567  loss_rpn_cls: 0.0001507  loss_rpn_loc: 0.0007342  time: 0.0741  data_time: 0.0020  lr: 0.0005  max_mem: 1161M
# ...
# [02/15 18:05:16 d2.utils.events]:  eta: 0:01:21  iter: 88859  total_loss: 0.009198  loss_cls: 0.0003456  loss_box_reg: 0.001594  loss_mask: 0.005933  loss_rpn_cls: 9.888e-05  loss_rpn_loc: 2.713e-05  time: 0.0741  data_time: 0.0020  lr: 5e-06  max_mem: 1161M
# [02/15 18:05:17 d2.utils.events]:  eta: 0:01:20  iter: 88879  total_loss: 0.008179  loss_cls: 0.0002607  loss_box_reg: 0.001063  loss_mask: 0.006444  loss_rpn_cls: 7.606e-05  loss_rpn_loc: 2.473e-05  time: 0.0741  data_time: 0.0019  lr: 5e-06  max_mem: 1161M
# [02/15 18:05:19 d2.utils.events]:  eta: 0:01:18  iter: 88899  total_loss: 0.008048  loss_cls: 0.0001178  loss_box_reg: 0.001103  loss_mask: 0.005809  loss_rpn_cls: 7.031e-05  loss_rpn_loc: 2.871e-05  time: 0.0741  data_time: 0.0019  lr: 5e-06  max_mem: 1161M
# [02/15 18:05:20 d2.utils.events]:  eta: 0:01:17  iter: 88919  total_loss: 0.008536  loss_cls: 0.0007046  loss_box_reg: 0.001374  loss_mask: 0.006212  loss_rpn_cls: 5.966e-05  loss_rpn_loc: 2.801e-05  time: 0.0741  data_time: 0.0019  lr: 5e-06  max_mem: 1161M
# [02/15 18:05:22 d2.utils.events]:  eta: 0:01:16  iter: 88939  total_loss: 0.009352  loss_cls: 0.0007501  loss_box_reg: 0.001339  loss_mask: 0.006476  loss_rpn_cls: 5.918e-05  loss_rpn_loc: 2.829e-05  time: 0.0741  data_time: 0.0019  lr: 5e-06  max_mem: 1161M
# [02/15 18:05:23 d2.utils.events]:  eta: 0:01:14  iter: 88959  total_loss: 0.008083  loss_cls: 0.0005552  loss_box_reg: 0.001315  loss_mask: 0.00598  loss_rpn_cls: 6.9e-05  loss_rpn_loc: 3.477e-05  time: 0.0741  data_time: 0.0019  lr: 5e-06  max_mem: 1161M
# [02/15 18:05:25 d2.utils.events]:  eta: 0:01:13  iter: 88979  total_loss: 0.009582  loss_cls: 0.0003873  loss_box_reg: 0.00113  loss_mask: 0.006115  loss_rpn_cls: 6.751e-05  loss_rpn_loc: 2.351e-05  time: 0.0741  data_time: 0.0019  lr: 5e-06  max_mem: 1161M
# [02/15 18:05:26 d2.utils.events]:  eta: 0:01:11  iter: 88999  total_loss: 0.008398  loss_cls: 0.0002067  loss_box_reg: 0.001511  loss_mask: 0.006389  loss_rpn_cls: 7.78e-05  loss_rpn_loc: 3.283e-05  time: 0.0741  data_time: 0.0020  lr: 5e-06  max_mem: 1161M
# [02/15 18:05:28 d2.utils.events]:  eta: 0:01:10  iter: 89019  total_loss: 0.009218  loss_cls: 0.0003036  loss_box_reg: 0.001662  loss_mask: 0.006304  loss_rpn_cls: 8.297e-05  loss_rpn_loc: 2.259e-05  time: 0.0741  data_time: 0.0020  lr: 5e-06  max_mem: 1161M
# [02/15 18:05:29 d2.utils.events]:  eta: 0:01:09  iter: 89039  total_loss: 0.008509  loss_cls: 0.000177  loss_box_reg: 0.001151  loss_mask: 0.006187  loss_rpn_cls: 6.817e-05  loss_rpn_loc: 2.379e-05  time: 0.0741  data_time: 0.0019  lr: 5e-06  max_mem: 1161M
# [02/15 18:05:31 d2.utils.events]:  eta: 0:01:07  iter: 89059  total_loss: 0.008877  loss_cls: 0.0007763  loss_box_reg: 0.001106  loss_mask: 0.006669  loss_rpn_cls: 8.356e-05  loss_rpn_loc: 2.869e-05  time: 0.0741  data_time: 0.0020  lr: 5e-06  max_mem: 1161M
# [02/15 18:05:32 d2.utils.events]:  eta: 0:01:06  iter: 89079  total_loss: 0.008884  loss_cls: 0.0004433  loss_box_reg: 0.001349  loss_mask: 0.006349  loss_rpn_cls: 7.908e-05  loss_rpn_loc: 2.123e-05  time: 0.0741  data_time: 0.0019  lr: 5e-06  max_mem: 1161M
# [02/15 18:05:33 d2.utils.events]:  eta: 0:01:05  iter: 89099  total_loss: 0.009777  loss_cls: 0.0005399  loss_box_reg: 0.00139  loss_mask: 0.006366  loss_rpn_cls: 8.241e-05  loss_rpn_loc: 1.999e-05  time: 0.0741  data_time: 0.0019  lr: 5e-06  max_mem: 1161M
# [02/15 18:05:35 d2.utils.events]:  eta: 0:01:03  iter: 89119  total_loss: 0.009012  loss_cls: 0.0003785  loss_box_reg: 0.001312  loss_mask: 0.006961  loss_rpn_cls: 7.67e-05  loss_rpn_loc: 2.356e-05  time: 0.0741  data_time: 0.0019  lr: 5e-06  max_mem: 1161M
# [02/15 18:05:36 d2.utils.events]:  eta: 0:01:02  iter: 89139  total_loss: 0.008958  loss_cls: 0.0004457  loss_box_reg: 0.001443  loss_mask: 0.005955  loss_rpn_cls: 7.537e-05  loss_rpn_loc: 2.388e-05  time: 0.0741  data_time: 0.0020  lr: 5e-06  max_mem: 1161M
# [02/15 18:05:38 d2.utils.events]:  eta: 0:01:00  iter: 89159  total_loss: 0.00867  loss_cls: 0.0003719  loss_box_reg: 0.001178  loss_mask: 0.006123  loss_rpn_cls: 5.388e-05  loss_rpn_loc: 2.031e-05  time: 0.0741  data_time: 0.0020  lr: 5e-06  max_mem: 1161M
# [02/15 18:05:39 d2.utils.events]:  eta: 0:00:59  iter: 89179  total_loss: 0.00868  loss_cls: 0.0006485  loss_box_reg: 0.001247  loss_mask: 0.006357  loss_rpn_cls: 8.285e-05  loss_rpn_loc: 2.215e-05  time: 0.0741  data_time: 0.0020  lr: 5e-06  max_mem: 1161M
# [02/15 18:05:41 d2.utils.events]:  eta: 0:00:57  iter: 89199  total_loss: 0.008986  loss_cls: 0.0003428  loss_box_reg: 0.00127  loss_mask: 0.006587  loss_rpn_cls: 6.865e-05  loss_rpn_loc: 2.417e-05  time: 0.0741  data_time: 0.0019  lr: 5e-06  max_mem: 1161M
# [02/15 18:05:42 d2.utils.events]:  eta: 0:00:56  iter: 89219  total_loss: 0.009179  loss_cls: 0.0003784  loss_box_reg: 0.00118  loss_mask: 0.006493  loss_rpn_cls: 6.83e-05  loss_rpn_loc: 2.41e-05  time: 0.0741  data_time: 0.0020  lr: 5e-06  max_mem: 1161M
# [02/15 18:05:44 d2.utils.events]:  eta: 0:00:55  iter: 89239  total_loss: 0.008586  loss_cls: 0.0004055  loss_box_reg: 0.001328  loss_mask: 0.005808  loss_rpn_cls: 8.163e-05  loss_rpn_loc: 2.351e-05  time: 0.0741  data_time: 0.0020  lr: 5e-06  max_mem: 1161M
# [02/15 18:05:45 d2.utils.events]:  eta: 0:00:53  iter: 89259  total_loss: 0.009235  loss_cls: 0.0002734  loss_box_reg: 0.001567  loss_mask: 0.006304  loss_rpn_cls: 7.265e-05  loss_rpn_loc: 3.064e-05  time: 0.0741  data_time: 0.0020  lr: 5e-06  max_mem: 1161M
# [02/15 18:05:47 d2.utils.events]:  eta: 0:00:52  iter: 89279  total_loss: 0.007739  loss_cls: 0.0002123  loss_box_reg: 0.001334  loss_mask: 0.005643  loss_rpn_cls: 6.823e-05  loss_rpn_loc: 3.015e-05  time: 0.0741  data_time: 0.0020  lr: 5e-06  max_mem: 1161M
# [02/15 18:05:48 d2.utils.events]:  eta: 0:00:50  iter: 89299  total_loss: 0.009116  loss_cls: 0.0002163  loss_box_reg: 0.001211  loss_mask: 0.005826  loss_rpn_cls: 8.9e-05  loss_rpn_loc: 2.331e-05  time: 0.0741  data_time: 0.0020  lr: 5e-06  max_mem: 1161M
# [02/15 18:05:50 d2.utils.events]:  eta: 0:00:49  iter: 89319  total_loss: 0.009062  loss_cls: 0.0004705  loss_box_reg: 0.0009225  loss_mask: 0.00618  loss_rpn_cls: 6.813e-05  loss_rpn_loc: 2.767e-05  time: 0.0741  data_time: 0.0020  lr: 5e-06  max_mem: 1161M
# [02/15 18:05:51 d2.utils.events]:  eta: 0:00:47  iter: 89339  total_loss: 0.008657  loss_cls: 0.0002346  loss_box_reg: 0.001172  loss_mask: 0.00651  loss_rpn_cls: 6.283e-05  loss_rpn_loc: 2.55e-05  time: 0.0741  data_time: 0.0020  lr: 5e-06  max_mem: 1161M
# [02/15 18:05:53 d2.utils.events]:  eta: 0:00:46  iter: 89359  total_loss: 0.008619  loss_cls: 0.0004738  loss_box_reg: 0.00106  loss_mask: 0.006123  loss_rpn_cls: 8.413e-05  loss_rpn_loc: 2.221e-05  time: 0.0741  data_time: 0.0020  lr: 5e-06  max_mem: 1161M
# [02/15 18:05:55 d2.utils.events]:  eta: 0:00:44  iter: 89379  total_loss: 0.00965  loss_cls: 0.0002964  loss_box_reg: 0.00118  loss_mask: 0.00602  loss_rpn_cls: 6.817e-05  loss_rpn_loc: 2.725e-05  time: 0.0741  data_time: 0.0022  lr: 5e-06  max_mem: 1161M
# [02/15 18:05:56 d2.utils.events]:  eta: 0:00:43  iter: 89399  total_loss: 0.008607  loss_cls: 0.0005083  loss_box_reg: 0.001184  loss_mask: 0.006295  loss_rpn_cls: 9.132e-05  loss_rpn_loc: 1.837e-05  time: 0.0741  data_time: 0.0020  lr: 5e-06  max_mem: 1161M
# [02/15 18:05:58 d2.utils.events]:  eta: 0:00:42  iter: 89419  total_loss: 0.008326  loss_cls: 0.000591  loss_box_reg: 0.001083  loss_mask: 0.006007  loss_rpn_cls: 7.213e-05  loss_rpn_loc: 2.47e-05  time: 0.0741  data_time: 0.0019  lr: 5e-06  max_mem: 1161M
# [02/15 18:05:59 d2.utils.events]:  eta: 0:00:40  iter: 89439  total_loss: 0.008864  loss_cls: 0.0001732  loss_box_reg: 0.001268  loss_mask: 0.006171  loss_rpn_cls: 0.000101  loss_rpn_loc: 2.268e-05  time: 0.0741  data_time: 0.0020  lr: 5e-06  max_mem: 1161M
# [02/15 18:06:01 d2.utils.events]:  eta: 0:00:39  iter: 89459  total_loss: 0.008765  loss_cls: 0.0003711  loss_box_reg: 0.001107  loss_mask: 0.006243  loss_rpn_cls: 8.056e-05  loss_rpn_loc: 2.77e-05  time: 0.0741  data_time: 0.0020  lr: 5e-06  max_mem: 1161M
# [02/15 18:06:03 d2.utils.events]:  eta: 0:00:37  iter: 89479  total_loss: 0.007825  loss_cls: 0.0002737  loss_box_reg: 0.001242  loss_mask: 0.005706  loss_rpn_cls: 7.182e-05  loss_rpn_loc: 1.776e-05  time: 0.0741  data_time: 0.0023  lr: 5e-06  max_mem: 1161M
# [02/15 18:06:04 d2.utils.events]:  eta: 0:00:36  iter: 89499  total_loss: 0.007899  loss_cls: 0.000164  loss_box_reg: 0.001113  loss_mask: 0.006014  loss_rpn_cls: 6.251e-05  loss_rpn_loc: 3.529e-05  time: 0.0741  data_time: 0.0022  lr: 5e-06  max_mem: 1161M
# [02/15 18:06:06 d2.utils.events]:  eta: 0:00:34  iter: 89519  total_loss: 0.007835  loss_cls: 9.059e-05  loss_box_reg: 0.001186  loss_mask: 0.005976  loss_rpn_cls: 7.242e-05  loss_rpn_loc: 2.29e-05  time: 0.0741  data_time: 0.0023  lr: 5e-06  max_mem: 1161M
# [02/15 18:06:08 d2.utils.events]:  eta: 0:00:33  iter: 89539  total_loss: 0.009388  loss_cls: 0.0008918  loss_box_reg: 0.001562  loss_mask: 0.005829  loss_rpn_cls: 5.673e-05  loss_rpn_loc: 2.862e-05  time: 0.0741  data_time: 0.0023  lr: 5e-06  max_mem: 1161M
# [02/15 18:06:10 d2.utils.events]:  eta: 0:00:32  iter: 89559  total_loss: 0.00931  loss_cls: 0.0003449  loss_box_reg: 0.00144  loss_mask: 0.005804  loss_rpn_cls: 9.711e-05  loss_rpn_loc: 2.293e-05  time: 0.0741  data_time: 0.0023  lr: 5e-06  max_mem: 1161M
# [02/15 18:06:12 d2.utils.events]:  eta: 0:00:30  iter: 89579  total_loss: 0.008875  loss_cls: 0.0006955  loss_box_reg: 0.001218  loss_mask: 0.006287  loss_rpn_cls: 8.772e-05  loss_rpn_loc: 2.942e-05  time: 0.0741  data_time: 0.0023  lr: 5e-06  max_mem: 1161M
# [02/15 18:06:14 d2.utils.events]:  eta: 0:00:29  iter: 89599  total_loss: 0.007993  loss_cls: 0.0004565  loss_box_reg: 0.001043  loss_mask: 0.00585  loss_rpn_cls: 7.609e-05  loss_rpn_loc: 2.594e-05  time: 0.0741  data_time: 0.0020  lr: 5e-06  max_mem: 1161M
# [02/15 18:06:15 d2.utils.events]:  eta: 0:00:27  iter: 89619  total_loss: 0.009456  loss_cls: 0.0001798  loss_box_reg: 0.001699  loss_mask: 0.005888  loss_rpn_cls: 7.444e-05  loss_rpn_loc: 2.362e-05  time: 0.0741  data_time: 0.0020  lr: 5e-06  max_mem: 1161M
# [02/15 18:06:17 d2.utils.events]:  eta: 0:00:26  iter: 89639  total_loss: 0.009279  loss_cls: 0.000479  loss_box_reg: 0.001265  loss_mask: 0.006023  loss_rpn_cls: 8.597e-05  loss_rpn_loc: 2.973e-05  time: 0.0741  data_time: 0.0020  lr: 5e-06  max_mem: 1161M
# [02/15 18:06:18 d2.utils.events]:  eta: 0:00:24  iter: 89659  total_loss: 0.008886  loss_cls: 0.0002949  loss_box_reg: 0.001378  loss_mask: 0.00708  loss_rpn_cls: 7.832e-05  loss_rpn_loc: 2.998e-05  time: 0.0741  data_time: 0.0020  lr: 5e-06  max_mem: 1161M
# [02/15 18:06:19 d2.utils.events]:  eta: 0:00:23  iter: 89679  total_loss: 0.007579  loss_cls: 0.000328  loss_box_reg: 0.001261  loss_mask: 0.005611  loss_rpn_cls: 8.3e-05  loss_rpn_loc: 2.472e-05  time: 0.0741  data_time: 0.0020  lr: 5e-06  max_mem: 1161M
# [02/15 18:06:21 d2.utils.events]:  eta: 0:00:21  iter: 89699  total_loss: 0.007623  loss_cls: 0.0001408  loss_box_reg: 0.001064  loss_mask: 0.005778  loss_rpn_cls: 8.665e-05  loss_rpn_loc: 3.396e-05  time: 0.0741  data_time: 0.0020  lr: 5e-06  max_mem: 1161M
# [02/15 18:06:23 d2.utils.events]:  eta: 0:00:20  iter: 89719  total_loss: 0.007999  loss_cls: 0.0004762  loss_box_reg: 0.001225  loss_mask: 0.006896  loss_rpn_cls: 6.516e-05  loss_rpn_loc: 1.902e-05  time: 0.0741  data_time: 0.0020  lr: 5e-06  max_mem: 1161M
# [02/15 18:06:24 d2.utils.events]:  eta: 0:00:18  iter: 89739  total_loss: 0.008169  loss_cls: 0.0002964  loss_box_reg: 0.001307  loss_mask: 0.006043  loss_rpn_cls: 9.735e-05  loss_rpn_loc: 2.272e-05  time: 0.0741  data_time: 0.0019  lr: 5e-06  max_mem: 1161M
# [02/15 18:06:25 d2.utils.events]:  eta: 0:00:17  iter: 89759  total_loss: 0.009644  loss_cls: 0.0002726  loss_box_reg: 0.001234  loss_mask: 0.006828  loss_rpn_cls: 6.655e-05  loss_rpn_loc: 3.005e-05  time: 0.0741  data_time: 0.0020  lr: 5e-06  max_mem: 1161M
# [02/15 18:06:27 d2.utils.events]:  eta: 0:00:15  iter: 89779  total_loss: 0.00882  loss_cls: 0.0005504  loss_box_reg: 0.001365  loss_mask: 0.006251  loss_rpn_cls: 0.0001224  loss_rpn_loc: 2.979e-05  time: 0.0741  data_time: 0.0021  lr: 5e-06  max_mem: 1161M
# [02/15 18:06:29 d2.utils.events]:  eta: 0:00:14  iter: 89799  total_loss: 0.008994  loss_cls: 0.0005732  loss_box_reg: 0.001274  loss_mask: 0.006071  loss_rpn_cls: 0.0001004  loss_rpn_loc: 2.642e-05  time: 0.0741  data_time: 0.0020  lr: 5e-06  max_mem: 1161M
# [02/15 18:06:30 d2.utils.events]:  eta: 0:00:13  iter: 89819  total_loss: 0.01035  loss_cls: 0.0005275  loss_box_reg: 0.001668  loss_mask: 0.006939  loss_rpn_cls: 7.12e-05  loss_rpn_loc: 2.582e-05  time: 0.0741  data_time: 0.0019  lr: 5e-06  max_mem: 1161M
# [02/15 18:06:32 d2.utils.events]:  eta: 0:00:11  iter: 89839  total_loss: 0.008897  loss_cls: 0.0001626  loss_box_reg: 0.001328  loss_mask: 0.006395  loss_rpn_cls: 7.425e-05  loss_rpn_loc: 2.684e-05  time: 0.0741  data_time: 0.0022  lr: 5e-06  max_mem: 1161M
# [02/15 18:06:34 d2.utils.events]:  eta: 0:00:10  iter: 89859  total_loss: 0.009012  loss_cls: 0.0006918  loss_box_reg: 0.0009779  loss_mask: 0.006622  loss_rpn_cls: 6.32e-05  loss_rpn_loc: 2.811e-05  time: 0.0741  data_time: 0.0023  lr: 5e-06  max_mem: 1161M
# [02/15 18:06:36 d2.utils.events]:  eta: 0:00:08  iter: 89879  total_loss: 0.01024  loss_cls: 0.0009075  loss_box_reg: 0.001357  loss_mask: 0.005837  loss_rpn_cls: 7.932e-05  loss_rpn_loc: 2.101e-05  time: 0.0741  data_time: 0.0023  lr: 5e-06  max_mem: 1161M
# [02/15 18:06:37 d2.utils.events]:  eta: 0:00:07  iter: 89899  total_loss: 0.00782  loss_cls: 0.0004866  loss_box_reg: 0.001289  loss_mask: 0.00552  loss_rpn_cls: 5.934e-05  loss_rpn_loc: 2.268e-05  time: 0.0741  data_time: 0.0020  lr: 5e-06  max_mem: 1161M
# [02/15 18:06:39 d2.utils.events]:  eta: 0:00:05  iter: 89919  total_loss: 0.008725  loss_cls: 0.0003911  loss_box_reg: 0.001226  loss_mask: 0.006382  loss_rpn_cls: 4.757e-05  loss_rpn_loc: 2.202e-05  time: 0.0741  data_time: 0.0023  lr: 5e-06  max_mem: 1161M
# [02/15 18:06:41 d2.utils.events]:  eta: 0:00:04  iter: 89939  total_loss: 0.008625  loss_cls: 0.0004124  loss_box_reg: 0.001272  loss_mask: 0.005671  loss_rpn_cls: 9.918e-05  loss_rpn_loc: 2.014e-05  time: 0.0741  data_time: 0.0022  lr: 5e-06  max_mem: 1161M
# [02/15 18:06:43 d2.utils.events]:  eta: 0:00:02  iter: 89959  total_loss: 0.008772  loss_cls: 0.0006848  loss_box_reg: 0.001157  loss_mask: 0.00644  loss_rpn_cls: 7.403e-05  loss_rpn_loc: 3.151e-05  time: 0.0741  data_time: 0.0020  lr: 5e-06  max_mem: 1161M
# [02/15 18:06:44 d2.utils.events]:  eta: 0:00:01  iter: 89979  total_loss: 0.01021  loss_cls: 0.0004625  loss_box_reg: 0.001775  loss_mask: 0.006792  loss_rpn_cls: 8.783e-05  loss_rpn_loc: 2.17e-05  time: 0.0741  data_time: 0.0019  lr: 5e-06  max_mem: 1161M
# [02/15 18:06:48 d2.utils.events]:  eta: 0:00:00  iter: 89999  total_loss: 0.008706  loss_cls: 0.0002569  loss_box_reg: 0.001267  loss_mask: 0.005539  loss_rpn_cls: 7.935e-05  loss_rpn_loc: 2.66e-05  time: 0.0741  data_time: 0.0020  lr: 5e-06  max_mem: 1161M
# [02/15 18:06:48 d2.engine.hooks]: Overall training speed: 89998 iterations in 1:51:11 (0.0741 s / it)
# [02/15 18:06:48 d2.engine.hooks]: Total training time: 1:53:34 (0:02:22 on hooks)
# [02/15 18:06:48 d2.data.build]: Distribution of instances among all 1 categories:
# |  category  | #instances   |
# |:----------:|:-------------|
# |  building  | 1            |
# |            |              |
# [02/15 18:06:48 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [02/15 18:06:48 d2.data.common]: Serializing 1 elements to byte tensors and concatenating them all ...
# [02/15 18:06:48 d2.data.common]: Serialized dataset takes 0.00 MiB
# WARNING [02/15 18:06:48 d2.engine.defaults]: No evaluator found. Use `DefaultTrainer.test(evaluators=)`, or implement its `build_evaluator` method.

# %%
# Verify GPU information
print (torch.cuda.is_available(), torch.cuda.device_count(), torch.cuda.current_device(), torch.cuda.device(0)
       , torch.cuda.get_device_name(0))

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
print()

# Additional info when using cuda
if device.type == 'cuda':
    print(torch.cuda.get_device_name(0))
    print('Memory Usage:')
    print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
    print('Cached:   ', round(torch.cuda.memory_reserved(0)/1024**3,1), 'GB')
# Out:
# True 1 0 <torch.cuda.device object at 0x15544342a070> NVIDIA A30
# Using device: cuda
#
# NVIDIA A30
# Memory Usage:
# Allocated: 0.0 GB
# Cached:    0.0 GB

# %% [markdown]
# total_loss: This is a weighted sum of the following individual losses calculated during the iteration. By default, the weights are all one.
#
# loss_cls: Classification loss in the ROI head. Measures the loss for box classification, i.e., how good the model is at labelling a predicted box with the correct class.
#
# loss_box_reg: Localisation loss in the ROI head. Measures the loss for box localisation (predicted location vs true location).
#
# loss_rpn_cls: Classification loss in the Region Proposal Network. Measures the "objectness" loss, i.e., how good the RPN is at labelling the anchor boxes as foreground or background.
#
# loss_rpn_loc: Localisation loss in the Region Proposal Network. Measures the loss for localisation of the predicted regions in the RPN.
#
# loss_mask: Mask loss in the Mask head. Measures how "correct" the predicted binary masks are.
#
# For more details on the losses (1) and (2), take a look at the Fast R-CNN paper and the code.
#
# For more details on the losses (3) and (4), take a look at the Faster R-CNN paper and the code.
#
# For more details on the loss (5), take a look at the Mask R-CNN paper and the code.

# %%
#.PY FILE:

def build_evaluator(cfg, dataset_name, output_folder=None):
    """
    Create evaluator(s) for a given dataset.
    This uses the special metadata "evaluator_type" associated with each builtin dataset.
    For your own dataset, you can simply create an evaluator manually in your
    script and do not have to worry about the hacky if-else logic here.
    """
    if output_folder is None:
        output_folder = os.path.join(cfg.OUTPUT_DIR, "inference")
    evaluator_list = []
    evaluator_type = MetadataCatalog.get(dataset_name).evaluator_type
    if evaluator_type in ["sem_seg", "coco_panoptic_seg"]:
        evaluator_list.append(
            SemSegEvaluator(
                dataset_name,
                distributed=True,
                output_dir=output_folder,
            )
        )
    if evaluator_type in ["coco", "coco_panoptic_seg"]:
        evaluator_list.append(COCOEvaluator(dataset_name, output_dir=output_folder))
    if evaluator_type == "coco_panoptic_seg":
        evaluator_list.append(COCOPanopticEvaluator(dataset_name, output_folder))
    if evaluator_type == "cityscapes_instance":
        return CityscapesInstanceEvaluator(dataset_name)
    if evaluator_type == "cityscapes_sem_seg":
        return CityscapesSemSegEvaluator(dataset_name)
    elif evaluator_type == "pascal_voc":
        return PascalVOCDetectionEvaluator(dataset_name)
    elif evaluator_type == "lvis":
        return LVISEvaluator(dataset_name, output_dir=output_folder)
    if len(evaluator_list) == 0:
        raise NotImplementedError(
            "no Evaluator for the dataset {} with the type {}".format(dataset_name, evaluator_type)
        )
    elif len(evaluator_list) == 1:
        return evaluator_list[0]
    return DatasetEvaluators(evaluator_list)


class Trainer(DefaultTrainer):
    """
    We use the "DefaultTrainer" which contains pre-defined default logic for
    standard training workflow. They may not work for you, especially if you
    are working on a new research project. In that case you can write your
    own training loop. You can use "tools/plain_train_net.py" as an example.
    """

    @classmethod
    def build_evaluator(cls, cfg, dataset_name, output_folder=None):
        return build_evaluator(cfg, dataset_name, output_folder)

    @classmethod
    def test_with_TTA(cls, cfg, model):
        logger = logging.getLogger("detectron2.trainer")
        # In the end of training, run an evaluation with TTA
        # Only support some R-CNN models.
        logger.info("Running inference with test-time augmentation ...")
        model = GeneralizedRCNNWithTTA(cfg, model)
        evaluators = [
            cls.build_evaluator(
                cfg, name, output_folder=os.path.join(cfg.OUTPUT_DIR, "inference_TTA")
            )
            for name in cfg.DATASETS.TEST
        ]
        res = cls.test(cfg, model, evaluators)
        res = OrderedDict({k + "_TTA": v for k, v in res.items()})
        return res


def setup(args):
    """
    Create configs and perform basic setups.
    """
    cfg = get_cfg()
    cfg.merge_from_file(args.config_file)
    cfg.merge_from_list(args.opts)
    cfg.freeze()
    default_setup(cfg, args)
    return cfg


def main(args):
    # Spacenet
    classes = ["asset"]
    
    for d in ["train", "val"]:
        DatasetCatalog.register(d, lambda d=d: get_dataset_dicts(os.path.join("NSO", d)))
        MetadataCatalog.get(d).thing_classes = classes
    
    cfg = setup(args)

    if args.eval_only:
        model = Trainer.build_model(cfg)
        DetectionCheckpointer(model, save_dir=cfg.OUTPUT_DIR).resume_or_load(
            cfg.MODEL.WEIGHTS, resume=args.resume
        )
        res = Trainer.test(cfg, model)
        if cfg.TEST.AUG.ENABLED:
            res.update(Trainer.test_with_TTA(cfg, model))
        if comm.is_main_process():
            verify_results(cfg, res)
        return res

    """
    If you'd like to do anything fancier than the standard training logic,
    consider writing your own training loop (see plain_train_net.py) or
    subclassing the trainer.
    """
    trainer = Trainer(cfg)
    trainer.resume_or_load(resume=args.resume)
    if cfg.TEST.AUG.ENABLED:
        trainer.register_hooks(
            [hooks.EvalHook(0, lambda: trainer.test_with_TTA(cfg, trainer.model))]
        )
    return trainer.train()


if __name__ == "__main__":
    args = default_argument_parser().parse_args()
    print("Command Line Args:", args)

    launch(
        main,
        args.num_gpus,
        num_machines=args.num_machines,
        machine_rank=args.machine_rank,
        dist_url=args.dist_url,
        args=(args,),
    )
